# %% [markdown]
# # Building Neural Network using NN module

# %%
from IPython.display import Image, display

listOfImageNames = ['mlp_mnist.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
