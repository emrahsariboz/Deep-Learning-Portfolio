# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %%
from collections import Counter
import numpy as np

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    if labels[i] == "POSITIVE":
        for words in reviews[i].split(" "):
            positive_counts[words] += 1
    else:
        for words in reviews[i].split(" "):
            negative_counts[words] += 1

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

for i in positive_counts.keys():
    if i in negative_counts.keys():
        pos_neg_ratios[i] = positive_counts[i] / float(negative_counts[i]+1)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0607993145235326
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902269426102881
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.7291085042663878

# %%
for key,value in pos_neg_ratios.items():
    pos_neg_ratios[key] = np.log(value)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902269426102881
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.7291085042663878

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('paulie', 59.0),
#  ('gundam', 30.666666666666668),
#  ('iturbi', 26.5),
#  ('giovanna', 24.0),
#  ('feinstone', 24.0),
#  ('felix', 23.4),
#  ('luzhin', 22.5),
#  ('philo', 21.5),
#  ('lindy', 21.0),
#  ('capote', 20.333333333333332),
#  ('fido', 20.25),
#  ('excellently', 19.666666666666668),
#  ('clutter', 19.5),
#  ('anchors', 19.0),
#  ('vance', 19.0),
#  ('kolchak', 18.75),
#  ('deanna', 18.666666666666668),
#  ('hayworth', 18.666666666666668),
#  ('korda', 17.5),
#  ('sammo', 17.333333333333332),
#  ('sox', 17.0),
#  ('laputa', 17.0),
#  ('biko', 17.0),
#  ('callahan', 17.0),
#  ('polanski', 16.833333333333332),
#  ('alvin', 16.75),
#  ('matthau', 16.555555555555557),
#  ('aiello', 16.5),
#  ('mathieu', 16.0),
#  ('adele', 15.666666666666666),
#  ('gackt', 15.666666666666666),
#  ('myrtle', 15.666666666666666),
#  ('bake', 15.5),
#  ('gilliam', 15.25),
#  ('bernsen', 15.0),
#  ('hickock', 15.0),
#  ('aviv', 15.0),
#  ('ashraf', 15.0),
#  ('gannon', 15.0),
#  ('eustache', 15.0),
#  ('victoria', 14.6),
#  ('beery', 14.5),
#  ('partition', 14.5),
#  ('dench', 14.5),
#  ('conroy', 14.5),
#  ('chavez', 14.4),
#  ('ratso', 14.2),
#  ('harriet', 14.0),
#  ('pang', 14.0),
#  ('ultimatum', 13.5),
#  ('mildred', 13.5),
#  ('fricker', 13.5),
#  ('emil', 13.5),
#  ('katsu', 13.5),
#  ('dev', 13.5),
#  ('mclaglen', 13.0),
#  ('saura', 13.0),
#  ('corbett', 12.8),
#  ('zu', 12.666666666666666),
#  ('abu', 12.666666666666666),
#  ('gandhi', 12.666666666666666),
#  ('sammi', 12.666666666666666),
#  ('warhols', 12.666666666666666),
#  ('delightfully', 12.5),
#  ('sirk', 12.428571428571429),
#  ('rosenstrasse', 12.333333333333334),
#  ('creasy', 12.25),
#  ('braveheart', 12.2),
#  ('unpretentious', 12.0),
#  ('kazan', 12.0),
#  ('lupino', 12.0),
#  ('perdition', 12.0),
#  ('blackadder', 12.0),
#  ('binder', 12.0),
#  ('yuzna', 12.0),
#  ('vonnegut', 11.75),
#  ('mccoy', 11.666666666666666),
#  ('taker', 11.666666666666666),
#  ('flawless', 11.6),
#  ('othello', 11.571428571428571),
#  ('abbey', 11.5),
#  ('natali', 11.5),
#  ('jonestown', 11.5),
#  ('godmother', 11.5),
#  ('judi', 11.5),
#  ('mahatma', 11.5),
#  ('mcnally', 11.5),
#  ('novak', 11.428571428571429),
#  ('durbin', 11.333333333333334),
#  ('christy', 11.25),
#  ('cheadle', 11.2),
#  ('fuller', 11.0),
#  ('radiant', 11.0),
#  ('woronov', 11.0),
#  ('ramones', 11.0),
#  ('noriko', 11.0),
#  ('waterman', 11.0),
#  ('pike', 11.0),
#  ('stockwell', 11.0),
#  ('pita', 10.666666666666666),
#  ('cal', 10.6),
#  ('reservations', 10.5),
#  ('elsa', 10.5),
#  ('johnston', 10.5),
#  ('brisson', 10.5),
#  ('schmid', 10.5),
#  ('oberon', 10.5),
#  ('marylee', 10.5),
#  ('winchester', 10.333333333333334),
#  ('jabba', 10.25),
#  ('chamberlain', 10.166666666666666),
#  ('rea', 10.0),
#  ('jud', 10.0),
#  ('montrose', 10.0),
#  ('ungar', 10.0),
#  ('haines', 10.0),
#  ('manny', 10.0),
#  ('bannister', 10.0),
#  ('colman', 10.0),
#  ('coop', 10.0),
#  ('girlfight', 10.0),
#  ('tigerland', 10.0),
#  ('flamenco', 10.0),
#  ('hundstage', 10.0),
#  ('homeward', 10.0),
#  ('carla', 9.75),
#  ('fagin', 9.75),
#  ('hanzo', 9.75),
#  ('aunts', 9.666666666666666),
#  ('olympia', 9.666666666666666),
#  ('sullavan', 9.666666666666666),
#  ('sabrina', 9.625),
#  ('superbly', 9.583333333333334),
#  ('sweetly', 9.5),
#  ('linklater', 9.5),
#  ('peters', 9.5),
#  ('zentropa', 9.5),
#  ('mccartney', 9.5),
#  ('gigi', 9.5),
#  ('hickok', 9.5),
#  ('tully', 9.5),
#  ('beetle', 9.5),
#  ('elia', 9.5),
#  ('aborigines', 9.5),
#  ('northam', 9.4),
#  ('tomlinson', 9.333333333333334),
#  ('tenant', 9.285714285714286),
#  ('influential', 9.25),
#  ('kalifornia', 9.25),
#  ('stardust', 9.2),
#  ('kinnear', 9.166666666666666),
#  ('complement', 9.0),
#  ('treasured', 9.0),
#  ('magnificently', 9.0),
#  ('raoul', 9.0),
#  ('vertigo', 9.0),
#  ('squire', 9.0),
#  ('hatcher', 9.0),
#  ('raines', 9.0),
#  ('benet', 9.0),
#  ('quartier', 9.0),
#  ('finely', 8.75),
#  ('stevenson', 8.75),
#  ('cheung', 8.75),
#  ('georges', 8.714285714285714),
#  ('perfection', 8.666666666666666),
#  ('rukh', 8.666666666666666),
#  ('marvelously', 8.666666666666666),
#  ('iris', 8.666666666666666),
#  ('weir', 8.666666666666666),
#  ('enchanting', 8.6),
#  ('sailing', 8.5),
#  ('celine', 8.5),
#  ('anand', 8.5),
#  ('astaire', 8.5),
#  ('province', 8.5),
#  ('leung', 8.5),
#  ('spellbinding', 8.5),
#  ('brodie', 8.5),
#  ('mahoney', 8.5),
#  ('cartwright', 8.5),
#  ('dixon', 8.5),
#  ('kennel', 8.5),
#  ('speakeasy', 8.5),
#  ('pressburger', 8.5),
#  ('curr', 8.5),
#  ('trier', 8.428571428571429),
#  ('pecker', 8.4),
#  ('miyazaki', 8.333333333333334),
#  ('wodehouse', 8.333333333333334),
#  ('vulnerability', 8.25),
#  ('hark', 8.25),
#  ('marjorie', 8.25),
#  ('darius', 8.25),
#  ('devotion', 8.2),
#  ('malone', 8.0),
#  ('genesis', 8.0),
#  ('abbot', 8.0),
#  ('mores', 8.0),
#  ('footlight', 8.0),
#  ('yang', 8.0),
#  ('tackled', 8.0),
#  ('romy', 8.0),
#  ('benoit', 8.0),
#  ('boothe', 8.0),
#  ('braun', 8.0),
#  ('devos', 8.0),
#  ('janeway', 8.0),
#  ('lupin', 8.0),
#  ('iago', 8.0),
#  ('fez', 8.0),
#  ('duryea', 8.0),
#  ('loomis', 8.0),
#  ('cheech', 7.8),
#  ('fairytale', 7.75),
#  ('tel', 7.75),
#  ('ella', 7.75),
#  ('askey', 7.75),
#  ('mol', 7.75),
#  ('captures', 7.68),
#  ('edith', 7.666666666666667),
#  ('quotable', 7.666666666666667),
#  ('tintin', 7.666666666666667),
#  ('curtiz', 7.666666666666667),
#  ('duchess', 7.666666666666667),
#  ('scoop', 7.625),
#  ('pickford', 7.625),
#  ('voight', 7.615384615384615),
#  ('wonderfully', 7.552631578947368),
#  ('goa', 7.5),
#  ('patekar', 7.5),
#  ('milton', 7.5),
#  ('dearly', 7.5),
#  ('richness', 7.5),
#  ('blaine', 7.5),
#  ('silvio', 7.5),
#  ('ephemeral', 7.5),
#  ('accomplishes', 7.5),
#  ('sasha', 7.5),
#  ('kessler', 7.5),
#  ('donnell', 7.5),
#  ('tetsuo', 7.5),
#  ('stubby', 7.5),
#  ('archibald', 7.5),
#  ('laird', 7.5),
#  ('gilley', 7.5),
#  ('stalkers', 7.5),
#  ('broomsticks', 7.5),
#  ('saffron', 7.5),
#  ('brokedown', 7.5),
#  ('zorro', 7.428571428571429),
#  ('clarence', 7.4),
#  ('dandy', 7.375),
#  ('heartbreaking', 7.333333333333333),
#  ('frailty', 7.333333333333333),
#  ('pawn', 7.333333333333333),
#  ('egan', 7.333333333333333),
#  ('pickpocket', 7.333333333333333),
#  ('bozz', 7.333333333333333),
#  ('venezuela', 7.25),
#  ('powell', 7.230769230769231),
#  ('wang', 7.2),
#  ('brosnan', 7.0625),
#  ('enthralling', 7.0),
#  ('transcends', 7.0),
#  ('masterful', 7.0),
#  ('mostel', 7.0),
#  ('ida', 7.0),
#  ('truman', 7.0),
#  ('stairway', 7.0),
#  ('refreshingly', 7.0),
#  ('hawke', 7.0),
#  ('strathairn', 7.0),
#  ('wtc', 7.0),
#  ('trebor', 7.0),
#  ('carre', 7.0),
#  ('singin', 7.0),
#  ('bafta', 7.0),
#  ('rathbone', 7.0),
#  ('francois', 7.0),
#  ('preity', 7.0),
#  ('henderson', 7.0),
#  ('slipper', 7.0),
#  ('argentine', 7.0),
#  ('meena', 7.0),
#  ('oshii', 7.0),
#  ('mala', 7.0),
#  ('collinwood', 7.0),
#  ('noll', 7.0),
#  ('aames', 7.0),
#  ('wegener', 7.0),
#  ('gingold', 7.0),
#  ('cratchit', 7.0),
#  ('sg', 6.875),
#  ('masterson', 6.875),
#  ('sunrise', 6.857142857142857),
#  ('lily', 6.823529411764706),
#  ('corbin', 6.8),
#  ('lila', 6.8),
#  ('expertly', 6.75),
#  ('lighten', 6.75),
#  ('adelaide', 6.75),
#  ('turturro', 6.75),
#  ('bakshi', 6.705882352941177),
#  ('lincoln', 6.695652173913044),
#  ('sumptuous', 6.666666666666667),
#  ('finlay', 6.666666666666667),
#  ('europa', 6.666666666666667),
#  ('firefighters', 6.666666666666667),
#  ('exquisitely', 6.666666666666667),
#  ('pabst', 6.666666666666667),
#  ('skagway', 6.666666666666667),
#  ('bhandarkar', 6.666666666666667),
#  ('darren', 6.636363636363637),
#  ('chang', 6.6),
#  ('booker', 6.6),
#  ('tomei', 6.571428571428571),
#  ('observant', 6.5),
#  ('blindness', 6.5),
#  ('butterflies', 6.5),
#  ('aborigine', 6.5),
#  ('lucile', 6.5),
#  ('superlative', 6.5),
#  ('collaborators', 6.5),
#  ('cypher', 6.5),
#  ('labyrinth', 6.5),
#  ('busby', 6.5),
#  ('ozzie', 6.5),
#  ('paget', 6.5),
#  ('stealer', 6.5),
#  ('ellie', 6.5),
#  ('holt', 6.5),
#  ('impressionist', 6.5),
#  ('informer', 6.5),
#  ('coccio', 6.5),
#  ('bulimia', 6.5),
#  ('lyman', 6.5),
#  ('spellbound', 6.5),
#  ('solicitor', 6.5),
#  ('lucienne', 6.5),
#  ('kher', 6.5),
#  ('kumari', 6.5),
#  ('cassavettes', 6.5),
#  ('borowczyk', 6.5),
#  ('bettany', 6.5),
#  ('ronda', 6.5),
#  ('iberia', 6.5),
#  ('rolle', 6.5),
#  ('maslin', 6.5),
#  ('schygulla', 6.5),
#  ('flik', 6.5),
#  ('greene', 6.428571428571429),
#  ('carell', 6.416666666666667),
#  ('sematary', 6.4),
#  ('refreshing', 6.392857142857143),
#  ('montana', 6.384615384615385),
#  ('pegg', 6.375),
#  ('breathtaking', 6.3478260869565215),
#  ('bourne', 6.346153846153846),
#  ('siu', 6.333333333333333),
#  ('electrifying', 6.333333333333333),
#  ('teri', 6.333333333333333),
#  ('splendidly', 6.333333333333333),
#  ('twisty', 6.333333333333333),
#  ('uncompromising', 6.333333333333333),
#  ('lemmon', 6.333333333333333),
#  ('prix', 6.333333333333333),
#  ('hardwicke', 6.333333333333333),
#  ('brock', 6.25),
#  ('abby', 6.25),
#  ('walsh', 6.25),
#  ('zelda', 6.25),
#  ('guiness', 6.25),
#  ('morbius', 6.25),
#  ('mendes', 6.25),
#  ('keeler', 6.2),
#  ('connolly', 6.2),
#  ('carface', 6.2),
#  ('zabriskie', 6.2),
#  ('batwoman', 6.2),
#  ('vincenzo', 6.166666666666667),
#  ('parrot', 6.142857142857143),
#  ('precise', 6.142857142857143),
#  ('explores', 6.1),
#  ('steele', 6.1),
#  ('delightful', 6.051282051282051),
#  ('flynn', 6.0476190476190474),
#  ('rory', 6.0),
#  ('heightens', 6.0),
#  ('examines', 6.0),
#  ('raja', 6.0),
#  ('parisian', 6.0),
#  ('travers', 6.0),
#  ('uproarious', 6.0),
#  ('crouse', 6.0),
#  ('breathes', 6.0),
#  ('marcus', 6.0),
#  ('robust', 6.0),
#  ('strides', 6.0),
#  ('nan', 6.0),
#  ('enforced', 6.0),
#  ('celebrates', 6.0),
#  ('witherspoon', 6.0),
#  ('champions', 6.0),
#  ('linden', 6.0),
#  ('franks', 6.0),
#  ('advent', 6.0),
#  ('weismuller', 6.0),
#  ('massey', 6.0),
#  ('undying', 6.0),
#  ('demunn', 6.0),
#  ('rogen', 6.0),
#  ('mischa', 6.0),
#  ('colonialism', 6.0),
#  ('strangler', 6.0),
#  ('evans', 6.0),
#  ('perseverance', 6.0),
#  ('leisen', 6.0),
#  ('rafael', 6.0),
#  ('talespin', 6.0),
#  ('tumultuous', 6.0),
#  ('patric', 6.0),
#  ('prem', 6.0),
#  ('trotta', 6.0),
#  ('nicolai', 6.0),
#  ('bearer', 6.0),
#  ('zandalee', 6.0),
#  ('auer', 6.0),
#  ('culp', 6.0),
#  ('runyon', 6.0),
#  ('shemp', 6.0),
#  ('jong', 6.0),
#  ('mower', 6.0),
#  ('dedlock', 6.0),
#  ('britton', 6.0),
#  ('conor', 6.0),
#  ('geddes', 6.0),
#  ('lumire', 6.0),
#  ('trejo', 6.0),
#  ('leia', 6.0),
#  ('corsaut', 6.0),
#  ('nath', 6.0),
#  ('tadashi', 6.0),
#  ('chess', 5.928571428571429),
#  ('andrews', 5.909090909090909),
#  ('homer', 5.866666666666666),
#  ('apartheid', 5.833333333333333),
#  ('beautifully', 5.828125),
#  ('friendships', 5.8),
#  ('soccer', 5.8),
#  ('foch', 5.8),
#  ('maclean', 5.8),
#  ('ira', 5.75),
#  ('deliciously', 5.75),
#  ('reginald', 5.75),
#  ('miners', 5.75),
#  ('todesking', 5.75),
#  ('lumet', 5.733333333333333),
#  ('affection', 5.7272727272727275),
#  ('bittersweet', 5.714285714285714),
#  ('cedric', 5.714285714285714),
#  ('elvira', 5.695652173913044),
#  ('axel', 5.666666666666667),
#  ('carrell', 5.666666666666667),
#  ('entranced', 5.666666666666667),
#  ('deft', 5.666666666666667),
#  ('bureaucracy', 5.666666666666667),
#  ('scorpion', 5.666666666666667),
#  ('silhouette', 5.666666666666667),
#  ('ilona', 5.666666666666667),
#  ('caprice', 5.666666666666667),
#  ('provo', 5.666666666666667),
#  ('shefali', 5.666666666666667),
#  ('dell', 5.666666666666667),
#  ('ullman', 5.666666666666667),
#  ('vulcan', 5.666666666666667),
#  ('radium', 5.666666666666667),
#  ('stepsisters', 5.666666666666667),
#  ('custer', 5.666666666666667),
#  ('hoon', 5.666666666666667),
#  ('kovacs', 5.666666666666667),
#  ('kidman', 5.636363636363637),
#  ('paperhouse', 5.6),
#  ('underrated', 5.583333333333333),
#  ('sopranos', 5.583333333333333),
#  ('quintessential', 5.571428571428571),
#  ('myrna', 5.571428571428571),
#  ('gripping', 5.565217391304348),
#  ('superb', 5.524271844660194),
#  ('rail', 5.5),
#  ('civilized', 5.5),
#  ('mastery', 5.5),
#  ('warms', 5.5),
#  ('buttgereit', 5.5),
#  ('perceptions', 5.5),
#  ('coveted', 5.5),
#  ('partnership', 5.5),
#  ('cameroon', 5.5),
#  ('expansion', 5.5),
#  ('extravagant', 5.5),
#  ('kibbee', 5.5),
#  ('mavens', 5.5),
#  ('doolittle', 5.5),
#  ('lassick', 5.5),
#  ('connecticut', 5.5),
#  ('rediscovered', 5.5),
#  ('criterion', 5.5),
#  ('pension', 5.5),
#  ('nina', 5.5),
#  ('expressionistic', 5.5),
#  ('celeste', 5.5),
#  ('minton', 5.5),
#  ('rippner', 5.5),
#  ('delon', 5.5),
#  ('snare', 5.5),
#  ('sternberg', 5.5),
#  ('dukakis', 5.5),
#  ('moonstruck', 5.5),
#  ('friel', 5.5),
#  ('montand', 5.5),
#  ('gallows', 5.5),
#  ('poirot', 5.5),
#  ('borden', 5.5),
#  ('gorshin', 5.5),
#  ('dickinson', 5.5),
#  ('eduardo', 5.5),
#  ('birdie', 5.5),
#  ('apollonia', 5.5),
#  ('nunsploitation', 5.5),
#  ('albuquerque', 5.5),
#  ('ealing', 5.428571428571429),
#  ('han', 5.428571428571429),
#  ('weaves', 5.4),
#  ('bagdad', 5.4),
#  ('paula', 5.4),
#  ('deliverance', 5.4),
#  ('holm', 5.4),
#  ('yoda', 5.4),
#  ('determination', 5.375),
#  ('romanticized', 5.333333333333333),
#  ('schmidt', 5.333333333333333),
#  ('krabbe', 5.333333333333333),
#  ('muller', 5.333333333333333),
#  ('sceptical', 5.333333333333333),
#  ('janice', 5.333333333333333),
#  ('jerome', 5.333333333333333),
#  ('bulldog', 5.333333333333333),
#  ('crashers', 5.333333333333333),
#  ('petition', 5.333333333333333),
#  ('doodlebops', 5.333333333333333),
#  ('scola', 5.333333333333333),
#  ('tierney', 5.333333333333333),
#  ('caleb', 5.333333333333333),
#  ('mvp', 5.333333333333333),
#  ('textile', 5.333333333333333),
#  ('delight', 5.32),
#  ('welles', 5.3),
#  ('reeve', 5.3),
#  ('zelah', 5.285714285714286),
#  ('sadness', 5.277777777777778),
#  ('accustomed', 5.25),
#  ('proposes', 5.25),
#  ('hermann', 5.25),
#  ('shia', 5.25),
#  ('palsy', 5.25),
#  ('meatball', 5.25),
#  ('technicolor', 5.230769230769231),
#  ('ae', 5.222222222222222),
#  ('maintained', 5.2),
#  ('tenderness', 5.2),
#  ('joyous', 5.2),
#  ('restoration', 5.2),
#  ('nicky', 5.2),
#  ('soylent', 5.2),
#  ('kline', 5.166666666666667),
#  ('sinatra', 5.15),
#  ('touching', 5.140845070422535),
#  ('stadium', 5.125),
#  ('marisa', 5.125),
#  ('gershwin', 5.111111111111111),
#  ('timeless', 5.1),
#  ('macy', 5.0588235294117645),
#  ('unforgettable', 5.041666666666667),
#  ('favorites', 5.032258064516129),
#  ('stewart', 5.012820512820513),
#  ('mammoth', 5.0),
#  ('extraordinary', 5.0),
#  ('shanks', 5.0),
#  ('hedy', 5.0),
#  ('ringo', 5.0),
#  ('perceptive', 5.0),
#  ('priorities', 5.0),
#  ('hoodlums', 5.0),
#  ('rugged', 5.0),
#  ('summertime', 5.0),
#  ('kurosawa', 5.0),
#  ('considerations', 5.0),
#  ('outstandingly', 5.0),
#  ('paxinou', 5.0),
#  ('duets', 5.0),
#  ('sorbonne', 5.0),
#  ('advancing', 5.0),
#  ('regency', 5.0),
#  ('mcgrath', 5.0),
#  ('compliments', 5.0),
#  ('unavailable', 5.0),
#  ('prelude', 5.0),
#  ('complexities', 5.0),
#  ('funhouse', 5.0),
#  ('sullivan', 5.0),
#  ('candid', 5.0),
#  ('judson', 5.0),
#  ('mammy', 5.0),
#  ('antidote', 5.0),
#  ('competitor', 5.0),
#  ('jonny', 5.0),
#  ('taft', 5.0),
#  ('pendleton', 5.0),
#  ('hartley', 5.0),
#  ('glacier', 5.0),
#  ('zenith', 5.0),
#  ('congrats', 5.0),
#  ('moulin', 5.0),
#  ('henri', 5.0),
#  ('panda', 5.0),
#  ('orphaned', 5.0),
#  ('internationally', 5.0),
#  ('dahlia', 5.0),
#  ('franchot', 5.0),
#  ('synthesis', 5.0),
#  ('blier', 5.0),
#  ('tsing', 5.0),
#  ('repulsion', 5.0),
#  ('cruz', 5.0),
#  ('weber', 5.0),
#  ('hahk', 5.0),
#  ('chico', 5.0),
#  ('bloch', 5.0),
#  ('grayson', 5.0),
#  ('restrictive', 5.0),
#  ('serrault', 5.0),
#  ('enforcer', 5.0),
#  ('noire', 5.0),
#  ('florinda', 5.0),
#  ('patten', 5.0),
#  ('taka', 5.0),
#  ('roberta', 5.0),
#  ('cocktails', 5.0),
#  ('wai', 5.0),
#  ('humanism', 5.0),
#  ('ponderosa', 5.0),
#  ('monarchy', 5.0),
#  ('duc', 5.0),
#  ('eytan', 5.0),
#  ('roshan', 5.0),
#  ('airwolf', 5.0),
#  ('breakdancing', 5.0),
#  ('kabal', 5.0),
#  ('nunez', 5.0),
#  ('grasshopper', 5.0),
#  ('retriever', 5.0),
#  ('meloni', 5.0),
#  ('everytown', 5.0),
#  ('lanchester', 5.0),
#  ('anansa', 5.0),
#  ('brilliantly', 4.928571428571429),
#  ('liu', 4.909090909090909),
#  ('clara', 4.909090909090909),
#  ('einstein', 4.909090909090909),
#  ('dustin', 4.9),
#  ('conductor', 4.875),
#  ('iran', 4.875),
#  ('shanghai', 4.857142857142857),
#  ('alienate', 4.833333333333333),
#  ('rainer', 4.833333333333333),
#  ('mesmerizing', 4.818181818181818),
#  ('raul', 4.8),
#  ('friendship', 4.795918367346939),
#  ('wonderful', 4.780487804878049),
#  ('seamlessly', 4.75),
#  ('heartwarming', 4.75),
#  ('companionship', 4.75),
#  ('trading', 4.75),
#  ('corinne', 4.75),
#  ('layered', 4.75),
#  ('eagle', 4.75),
#  ('moriarty', 4.75),
#  ('scarlett', 4.75),
#  ('swordplay', 4.75),
#  ('cheryl', 4.75),
#  ('demme', 4.75),
#  ('amicus', 4.75),
#  ('sergeants', 4.75),
#  ('palma', 4.7368421052631575),
#  ('watson', 4.733333333333333),
#  ('wrenching', 4.7272727272727275),
#  ('fairbanks', 4.7),
#  ('magnificent', 4.695652173913044),
#  ('finest', 4.6938775510204085),
#  ('understated', 4.6875),
#  ('jackie', 4.682926829268292),
#  ('doggie', 4.666666666666667),
#  ('serene', 4.666666666666667),
#  ('compellingly', 4.666666666666667),
#  ('grifters', 4.666666666666667),
#  ('simmons', 4.666666666666667),
#  ('snatched', 4.666666666666667),
#  ('sensitively', 4.666666666666667),
#  ('regal', 4.666666666666667),
#  ('election', 4.666666666666667),
#  ('hampton', 4.666666666666667),
#  ('resonates', 4.666666666666667),
#  ('ritter', 4.666666666666667),
#  ('undercurrent', 4.666666666666667),
#  ('opposites', 4.666666666666667),
#  ('expressionism', 4.666666666666667),
#  ('merrill', 4.666666666666667),
#  ('analyzed', 4.666666666666667),
#  ('liza', 4.666666666666667),
#  ('delirious', 4.666666666666667),
#  ('johansson', 4.666666666666667),
#  ('swashbuckling', 4.666666666666667),
#  ('riker', 4.666666666666667),
#  ('miramax', 4.666666666666667),
#  ('diver', 4.666666666666667),
#  ('avery', 4.666666666666667),
#  ('braga', 4.666666666666667),
#  ('seidl', 4.666666666666667),
#  ('sooraj', 4.666666666666667),
#  ('captivated', 4.625),
#  ('relaxed', 4.625),
#  ('fritz', 4.625),
#  ('lang', 4.6),
#  ('connelly', 4.6),
#  ('lyle', 4.6),
#  ('rowlands', 4.6),
#  ('jaffe', 4.6),
#  ('conflicted', 4.571428571428571),
#  ('maturity', 4.571428571428571),
#  ('gently', 4.571428571428571),
#  ('showcases', 4.571428571428571),
#  ('tremendous', 4.565217391304348),
#  ('conveys', 4.538461538461538),
#  ('buffalo', 4.533333333333333),
#  ('nathan', 4.533333333333333),
#  ('scrooge', 4.529411764705882),
#  ('freedom', 4.5227272727272725),
#  ('fantastic', 4.503448275862069),
#  ('bracelet', 4.5),
#  ('murdoch', 4.5),
#  ('astor', 4.5),
#  ('realist', 4.5),
#  ('permits', 4.5),
#  ('composure', 4.5),
#  ('planets', 4.5),
#  ('tart', 4.5),
#  ('escalates', 4.5),
#  ('tapestry', 4.5),
#  ('unrestrained', 4.5),
#  ('albums', 4.5),
#  ('progressing', 4.5),
#  ('starlets', 4.5),
#  ('settling', 4.5),
#  ('rarer', 4.5),
#  ('yuen', 4.5),
#  ('blondell', 4.5),
#  ('sweetheart', 4.5),
#  ('vigorous', 4.5),
#  ('barrie', 4.5),
#  ('demolished', 4.5),
#  ('mischievous', 4.5),
#  ('duplicated', 4.5),
#  ('amsterdam', 4.5),
#  ('introverted', 4.5),
#  ('structures', 4.5),
#  ('interacted', 4.5),
#  ('underscored', 4.5),
#  ('crowe', 4.5),
#  ('riotous', 4.5),
#  ('illusions', 4.5),
#  ('fai', 4.5),
#  ('poppins', 4.5),
#  ('predicaments', 4.5),
#  ('attest', 4.5),
#  ('piggy', 4.5),
#  ('erected', 4.5),
#  ('longs', 4.5),
#  ('te', 4.5),
#  ('tinker', 4.5),
#  ('agamemnon', 4.5),
#  ('optical', 4.5),
#  ('rosalind', 4.5),
#  ('resonant', 4.5),
#  ('voicing', 4.5),
#  ('pawns', 4.5),
#  ('lydia', 4.5),
#  ('intercontinental', 4.5),
#  ('dictator', 4.5),
#  ('una', 4.5),
#  ('carne', 4.5),
#  ('impulsive', 4.5),
#  ('orbach', 4.5),
#  ('elliott', 4.5),
#  ('inexorably', 4.5),
#  ('thesiger', 4.5),
#  ('manuel', 4.5),
#  ('detained', 4.5),
#  ('cate', 4.5),
#  ('mimes', 4.5),
#  ('shohei', 4.5),
#  ('sarafina', 4.5),
#  ('nielsen', 4.5),
#  ('hingle', 4.5),
#  ('gleaming', 4.5),
#  ('daz', 4.5),
#  ('spatula', 4.5),
#  ('chu', 4.5),
#  ('binnie', 4.5),
#  ('matsumoto', 4.5),
#  ('stoolie', 4.5),
#  ('mariette', 4.5),
#  ('chabat', 4.5),
#  ('nablus', 4.5),
#  ('elam', 4.5),
#  ('jonah', 4.5),
#  ('batista', 4.5),
#  ('yokozuna', 4.5),
#  ('hearn', 4.5),
#  ('bowler', 4.5),
#  ('yonica', 4.5),
#  ('tamerlane', 4.5),
#  ('gretchen', 4.5),
#  ('batgirl', 4.5),
#  ('inarritu', 4.5),
#  ('aneta', 4.5),
#  ('terrific', 4.493670886075949),
#  ('spock', 4.470588235294118),
#  ('noir', 4.454545454545454),
#  ('loy', 4.454545454545454),
#  ('sidney', 4.454545454545454),
#  ('benefits', 4.444444444444445),
#  ('diego', 4.444444444444445),
#  ('cena', 4.444444444444445),
#  ('shahid', 4.444444444444445),
#  ('outstanding', 4.441558441558442),
#  ('mann', 4.434782608695652),
#  ('pleasantly', 4.434782608695652),
#  ('heartfelt', 4.428571428571429),
#  ('cloth', 4.428571428571429),
#  ('nancy', 4.428571428571429),
#  ('marie', 4.404255319148936),
#  ('fateful', 4.4),
#  ('humane', 4.4),
#  ('akira', 4.4),
#  ('trey', 4.4),
#  ('hyde', 4.388888888888889),
#  ('marvelous', 4.366666666666666),
#  ('odyssey', 4.363636363636363),
#  ('astonishing', 4.333333333333333),
#  ('emotive', 4.333333333333333),
#  ('dystopian', 4.333333333333333),
#  ('intricacies', 4.333333333333333),
#  ('blends', 4.333333333333333),
#  ('juxtaposition', 4.333333333333333),
#  ('unflinching', 4.333333333333333),
#  ('donovan', 4.333333333333333),
#  ('distressed', 4.333333333333333),
#  ('andre', 4.333333333333333),
#  ('sneaky', 4.333333333333333),
#  ('plato', 4.333333333333333),
#  ('banjo', 4.333333333333333),
#  ('hastings', 4.333333333333333),
#  ('stack', 4.333333333333333),
#  ('andr', 4.333333333333333),
#  ('embraces', 4.333333333333333),
#  ('vanities', 4.333333333333333),
#  ('infernal', 4.333333333333333),
#  ('addictions', 4.333333333333333),
#  ('coen', 4.333333333333333),
#  ('collaborator', 4.333333333333333),
#  ('irs', 4.333333333333333),
#  ('shivers', 4.333333333333333),
#  ('postman', 4.333333333333333),
#  ('stifling', 4.333333333333333),
#  ('centerpiece', 4.333333333333333),
#  ('balsam', 4.333333333333333),
#  ('mulholland', 4.333333333333333),
#  ('tanner', 4.333333333333333),
#  ('waco', 4.333333333333333),
#  ('sampson', 4.333333333333333),
#  ('indelible', 4.333333333333333),
#  ('loveable', 4.333333333333333),
#  ('gardiner', 4.333333333333333),
#  ('gertrude', 4.333333333333333),
#  ('inevitability', 4.333333333333333),
#  ('nair', 4.333333333333333),
#  ('watanabe', 4.333333333333333),
#  ('rays', 4.333333333333333),
#  ('celie', 4.333333333333333),
#  ('sherry', 4.333333333333333),
#  ('stormtroopers', 4.333333333333333),
#  ('izo', 4.333333333333333),
#  ('suleiman', 4.333333333333333),
#  ('excellent', 4.326478149100257),
#  ('delicate', 4.3076923076923075),
#  ('ruth', 4.304347826086956),
#  ('sondra', 4.3),
#  ('climate', 4.285714285714286),
#  ('metropolis', 4.285714285714286),
#  ('maguire', 4.285714285714286),
#  ('kitty', 4.285714285714286),
#  ('sidewalk', 4.2727272727272725),
#  ('absorbing', 4.2727272727272725),
#  ('longing', 4.2727272727272725),
#  ('cunningham', 4.2727272727272725),
#  ('wei', 4.25),
#  ('stargate', 4.25),
#  ('jafar', 4.25),
#  ('affectionate', 4.25),
#  ('lan', 4.25),
#  ('spall', 4.25),
#  ('jos', 4.25),
#  ('rouge', 4.25),
#  ('irving', 4.25),
#  ('macgregor', 4.25),
#  ('pickup', 4.25),
#  ('michell', 4.25),
#  ('jedi', 4.25),
#  ('stanwyck', 4.225806451612903),
#  ('riff', 4.222222222222222),
#  ('sassy', 4.214285714285714),
#  ('fontaine', 4.214285714285714),
#  ('macarthur', 4.2105263157894735),
#  ('tragedies', 4.2),
#  ('evolves', 4.2),
#  ('adversity', 4.2),
#  ('jose', 4.2),
#  ('affluent', 4.2),
#  ('soprano', 4.2),
#  ('outlaws', 4.2),
#  ('wickedly', 4.2),
#  ('illinois', 4.2),
#  ('denholm', 4.2),
#  ('widmark', 4.2),
#  ('hadley', 4.181818181818182),
#  ('detract', 4.166666666666667),
#  ('splendid', 4.166666666666667),
#  ('infectious', 4.166666666666667),
#  ('thaw', 4.166666666666667),
#  ('caf', 4.166666666666667),
#  ('alain', 4.166666666666667),
#  ('formidable', 4.166666666666667),
#  ('layers', 4.153846153846154),
#  ('chan', 4.15),
#  ('exceptional', 4.137931034482759),
#  ('stark', 4.133333333333334),
#  ('floriane', 4.125),
#  ('daria', 4.125),
#  ('ewoks', 4.125),
#  ('tender', 4.1),
#  ('iranian', 4.1),
#  ('demille', 4.090909090909091),
#  ('jacques', 4.090909090909091),
#  ('gielgud', 4.090909090909091),
#  ('gentle', 4.086956521739131),
#  ('definitive', 4.083333333333333),
#  ('denis', 4.071428571428571),
#  ('poignant', 4.064516129032258),
#  ('ruby', 4.052631578947368),
#  ('gem', 4.027777777777778),
#  ('amazing', 4.022813688212928),
#  ('fisher', 4.0),
#  ('chilling', 4.0),
#  ('rousing', 4.0),
#  ('testimony', 4.0),
#  ('villaronga', 4.0),
#  ('calvert', 4.0),
#  ('luminous', 4.0),
#  ('betrothed', 4.0),
#  ('eroticism', 4.0),
#  ('naturalness', 4.0),
#  ('menial', 4.0),
#  ('dickens', 4.0),
#  ('pereira', 4.0),
#  ('govind', 4.0),
#  ('teal', 4.0),
#  ('captivating', 4.0),
#  ('dripped', 4.0),
#  ('taut', 4.0),
#  ('palpable', 4.0),
#  ('enhances', 4.0),
#  ('farscape', 4.0),
#  ('delved', 4.0),
#  ('merge', 4.0),
#  ('nascent', 4.0),
#  ('entertains', 4.0),
#  ('pip', 4.0),
#  ('madge', 4.0),
#  ('powerfully', 4.0),
#  ('tung', 4.0),
#  ...]

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('boll', 0.006944444444444444),
#  ('uwe', 0.00980392156862745),
#  ('thunderbirds', 0.016129032258064516),
#  ('beowulf', 0.01639344262295082),
#  ('dahmer', 0.018518518518518517),
#  ('wayans', 0.0196078431372549),
#  ('ajay', 0.020833333333333332),
#  ('grendel', 0.020833333333333332),
#  ('awfulness', 0.02564102564102564),
#  ('seagal', 0.026143790849673203),
#  ('steaming', 0.02631578947368421),
#  ('welch', 0.02702702702702703),
#  ('deathstalker', 0.02857142857142857),
#  ('sabretooth', 0.03225806451612903),
#  ('interminable', 0.03225806451612903),
#  ('forwarding', 0.03333333333333333),
#  ('devgan', 0.034482758620689655),
#  ('gamera', 0.03571428571428571),
#  ('varma', 0.037037037037037035),
#  ('picker', 0.037037037037037035),
#  ('razzie', 0.037037037037037035),
#  ('dreck', 0.0379746835443038),
#  ('unwatchable', 0.038461538461538464),
#  ('nada', 0.04),
#  ('stinker', 0.04040404040404041),
#  ('kirkland', 0.041666666666666664),
#  ('nostril', 0.041666666666666664),
#  ('giamatti', 0.041666666666666664),
#  ('aag', 0.043478260869565216),
#  ('demi', 0.043478260869565216)]
