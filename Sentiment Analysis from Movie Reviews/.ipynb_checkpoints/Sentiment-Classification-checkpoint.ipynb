# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %%
from collections import Counter
import numpy as np

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    if labels[i] == "POSITIVE":
        for words in reviews[i].split(" "):
            positive_counts[words] += 1
            total_counts[words] += 1
    else:
        for words in reviews[i].split(" "):
            negative_counts[words] += 1
            total_counts[words] += 1
            
len(positive_counts) + len (negative_counts) 

#Words in Labels

total_words_in_labels = Counter()

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

for i in positive_counts.keys():
    if i in negative_counts.keys():
        pos_neg_ratios[i] = positive_counts[i] / float(negative_counts[i]+1)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0607993145235326
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0607993145235326
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %%
for key,value in pos_neg_ratios.items():
    pos_neg_ratios[key] = np.log(value)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902269426102881
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.7291085042663878

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()[:5]
# Out:
# [('paulie', 4.07753744390572),
#  ('gundam', 3.4231762883809305),
#  ('iturbi', 3.2771447329921766),
#  ('giovanna', 3.1780538303479458),
#  ('feinstone', 3.1780538303479458)]

# %%
list(reversed(pos_neg_ratios.most_common()))[0:5]
# Out:
# [('boll', -4.969813299576001),
#  ('uwe', -4.624972813284271),
#  ('thunderbirds', -4.127134385045092),
#  ('beowulf', -4.110873864173311),
#  ('dahmer', -3.9889840465642745)]

# %% [markdown]
# # Transforming Text into Numbers<a id='lesson_3'></a>

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"


Image(filename='sentiment_network_pos.png')

# %%
vocab = set(total_counts.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %%
Image(filename='sentiment_network_2.png')

# %%
layer_0 = np.zeros(shape=(1,vocab_size))
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i

# %% [markdown]
#  `update_input_layer` should count how many times each word is used in the given review, and then store those counts at the appropriate indices inside `layer_0`. Remember: layer_0 is (1xvocab_size). It is a vector that stores the total number of word in corresponding index

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    counter = Counter()
    
    for i in review.split(" "):
        counter[i] += 1
    
    
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1
# TODO: count how many times each word is used in the given review and store the results in layer_0

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
def get_target_for_label(label):
    if label == "POSITIVE":
        return 1
    return 0
    # TODO: Your code here

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %%
import time
import sys
import numpy as np

# %%
# Encapsulate neural network
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden__nodes = 5, learning_rate = 0.1):
        
        np.random.seed(1)
                
        self.pre_process_data(reviews, labels)

        self.init_network(len(self.review_vocab),hidden__nodes, 1, learning_rate)

    
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        
        for i in reviews:
            for j in i.split(' '):
                review_vocab.add(j)
   
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()

        
        for i in labels:
            for j in i.split(' '):
                label_vocab.add(j)
        
        
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        for index, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
     
        for index, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
        
        
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros(shape=(1,input_nodes))
    
    
    def get_target_for_label(self, label):
        if label == "POSITIVE": 
            return 1
        return 0
    
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        #Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1 - output)
    
    def update_input_layer(self,review):
        
        """
        Global layer_0 represents the vector form of review.
        The element at a given index of layer_0 should represent
        how many times the given word occurs in the review.
        """
        
        
        self.layer_0 *= 0
        counter = Counter()

        for i in review.split(" "):
            counter[i] += 1
                
        for keys, values in counter.items():
            index = word2index[keys]
            layer_0[0][index] = values
        
        print('The shape of layer_0 is ', layer_0.shape)
            
    
    
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            correct_label = training_labels[i]
            
            #Input Layer
            self.update_input_layer(review)
            
            #Hidden Layer (no linearity)
            layer_1 = self.layer_0.dot(self.weights_0_1)
            
            #Output Layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #Error Calculation
            layer_2_error = layer_2 - self.get_target_for_label(correct_label)
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            
            #Backpropagation Error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T)
            layer_1_delta = layer_1_error 

            
            #Update weights 
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate
            
            
            # Keep track of correct predictions. To determine if the prediction was
            # correct, check that the absolute value of the output error 
            # is less than 0.5. If so, add one to the correct_so_far count.
            
            
            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and correct_label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and correct_label == 'NEGATIVE'):
                correct_so_far += 1
            
            
            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
        
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct+=1
                        
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        reviews = review.lower()
        
        self.update_input_layer(review)
            
        #Hidden Layer (no linearity)
        layer_1 = self.layer_0.dot(self.weights_0_1)
            
        #Output Layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if layer_2[0] > 0.5:
            return "POSITIVE"
        return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)

# %%
#mlp.test(reviews[-1000:],labels[-1000:])

# %%
mlp.train(reviews[:-20], labels[:-20])
# Out:
# The shape of layer_0 is  (1, 74074)
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# The shape of layer_0 is  (1, 74074)
# Progress:0.00% Speed(reviews/sec):91.15 #Correct:0 #Trained:2 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.00% Speed(reviews/sec):117.9 #Correct:0 #Trained:3 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.01% Speed(reviews/sec):130.7 #Correct:0 #Trained:4 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.01% Speed(reviews/sec):138.2 #Correct:0 #Trained:5 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):143.2 #Correct:0 #Trained:6 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):150.4 #Correct:0 #Trained:7 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):152.5 #Correct:0 #Trained:8 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.03% Speed(reviews/sec):157.2 #Correct:0 #Trained:9 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.03% Speed(reviews/sec):161.1 #Correct:0 #Trained:10 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.04% Speed(reviews/sec):164.3 #Correct:0 #Trained:11 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.04% Speed(reviews/sec):169.6 #Correct:0 #Trained:12 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):171.8 #Correct:0 #Trained:13 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):173.7 #Correct:0 #Trained:14 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):177.6 #Correct:0 #Trained:15 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.06% Speed(reviews/sec):179.0 #Correct:0 #Trained:16 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.06% Speed(reviews/sec):180.2 #Correct:0 #Trained:17 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):183.2 #Correct:0 #Trained:18 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):182.3 #Correct:0 #Trained:19 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):184.9 #Correct:0 #Trained:20 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.08% Speed(reviews/sec):185.6 #Correct:0 #Trained:21 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.08% Speed(reviews/sec):186.3 #Correct:0 #Trained:22 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.09% Speed(reviews/sec):186.9 #Correct:0 #Trained:23 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.09% Speed(reviews/sec):187.4 #Correct:0 #Trained:24 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.1% Speed(reviews/sec):188.0 #Correct:0 #Trained:25 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.10% Speed(reviews/sec):189.9 #Correct:0 #Trained:26 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.10% Speed(reviews/sec):190.2 #Correct:0 #Trained:27 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.11% Speed(reviews/sec):190.6 #Correct:0 #Trained:28 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.11% Speed(reviews/sec):192.2 #Correct:0 #Trained:29 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):192.5 #Correct:0 #Trained:30 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):191.5 #Correct:0 #Trained:31 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):190.6 #Correct:0 #Trained:32 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.13% Speed(reviews/sec):190.9 #Correct:0 #Trained:33 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.13% Speed(reviews/sec):190.1 #Correct:0 #Trained:34 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.14% Speed(reviews/sec):190.4 #Correct:0 #Trained:35 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.14% Speed(reviews/sec):190.7 #Correct:0 #Trained:36 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):190.9 #Correct:0 #Trained:37 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):191.2 #Correct:0 #Trained:38 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):191.4 #Correct:0 #Trained:39 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.16% Speed(reviews/sec):191.6 #Correct:0 #Trained:40 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.16% Speed(reviews/sec):190.9 #Correct:0 #Trained:41 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):192.2 #Correct:0 #Trained:42 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):192.3 #Correct:0 #Trained:43 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):191.7 #Correct:0 #Trained:44 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.18% Speed(reviews/sec):191.9 #Correct:0 #Trained:45 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.18% Speed(reviews/sec):192.0 #Correct:0 #Trained:46 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.19% Speed(reviews/sec):192.2 #Correct:0 #Trained:47 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.19% Speed(reviews/sec):192.4 #Correct:0 #Trained:48 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.2% Speed(reviews/sec):192.6 #Correct:0 #Trained:49 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.20% Speed(reviews/sec):192.7 #Correct:0 #Trained:50 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.20% Speed(reviews/sec):193.6 #Correct:0 #Trained:51 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.21% Speed(reviews/sec):193.0 #Correct:0 #Trained:52 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.21% Speed(reviews/sec):193.1 #Correct:0 #Trained:53 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):194.0 #Correct:0 #Trained:54 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):194.1 #Correct:0 #Trained:55 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):193.5 #Correct:0 #Trained:56 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.23% Speed(reviews/sec):194.3 #Correct:0 #Trained:57 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.23% Speed(reviews/sec):194.4 #Correct:0 #Trained:58 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.24% Speed(reviews/sec):193.9 #Correct:0 #Trained:59 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.24% Speed(reviews/sec):194.6 #Correct:0 #Trained:60 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):194.7 #Correct:0 #Trained:61 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):194.8 #Correct:0 #Trained:62 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):194.9 #Correct:0 #Trained:63 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.26% Speed(reviews/sec):195.0 #Correct:0 #Trained:64 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.26% Speed(reviews/sec):195.7 #Correct:0 #Trained:65 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):195.7 #Correct:0 #Trained:66 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):195.2 #Correct:0 #Trained:67 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):195.3 #Correct:0 #Trained:68 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.28% Speed(reviews/sec):195.4 #Correct:0 #Trained:69 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.28% Speed(reviews/sec):195.5 #Correct:0 #Trained:70 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.29% Speed(reviews/sec):195.5 #Correct:0 #Trained:71 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.29% Speed(reviews/sec):195.6 #Correct:0 #Trained:72 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.3% Speed(reviews/sec):195.1 #Correct:0 #Trained:73 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.30% Speed(reviews/sec):194.1 #Correct:0 #Trained:74 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.30% Speed(reviews/sec):194.2 #Correct:0 #Trained:75 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.31% Speed(reviews/sec):194.8 #Correct:0 #Trained:76 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.31% Speed(reviews/sec):194.9 #Correct:0 #Trained:77 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):194.5 #Correct:0 #Trained:78 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):194.1 #Correct:0 #Trained:79 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):194.1 #Correct:0 #Trained:80 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.33% Speed(reviews/sec):194.2 #Correct:0 #Trained:81 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.33% Speed(reviews/sec):194.3 #Correct:0 #Trained:82 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.34% Speed(reviews/sec):194.8 #Correct:0 #Trained:83 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.34% Speed(reviews/sec):194.9 #Correct:0 #Trained:84 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):195.0 #Correct:0 #Trained:85 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):195.5 #Correct:0 #Trained:86 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):195.5 #Correct:0 #Trained:87 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.36% Speed(reviews/sec):195.6 #Correct:0 #Trained:88 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.36% Speed(reviews/sec):196.1 #Correct:0 #Trained:89 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):196.5 #Correct:0 #Trained:90 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):196.6 #Correct:0 #Trained:91 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):196.6 #Correct:0 #Trained:92 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.38% Speed(reviews/sec):197.1 #Correct:0 #Trained:93 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.38% Speed(reviews/sec):197.1 #Correct:0 #Trained:94 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.39% Speed(reviews/sec):197.6 #Correct:0 #Trained:95 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.39% Speed(reviews/sec):198.0 #Correct:0 #Trained:96 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.4% Speed(reviews/sec):198.5 #Correct:0 #Trained:97 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.40% Speed(reviews/sec):198.5 #Correct:0 #Trained:98 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.40% Speed(reviews/sec):198.5 #Correct:0 #Trained:99 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.41% Speed(reviews/sec):198.9 #Correct:0 #Trained:100 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.41% Speed(reviews/sec):199.3 #Correct:0 #Trained:101 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):199.7 #Correct:0 #Trained:102 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):199.7 #Correct:0 #Trained:103 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):200.1 #Correct:0 #Trained:104 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.43% Speed(reviews/sec):200.5 #Correct:0 #Trained:105 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.43% Speed(reviews/sec):200.5 #Correct:0 #Trained:106 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.44% Speed(reviews/sec):200.5 #Correct:0 #Trained:107 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.44% Speed(reviews/sec):200.5 #Correct:0 #Trained:108 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):200.5 #Correct:0 #Trained:109 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):200.9 #Correct:0 #Trained:110 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):200.9 #Correct:0 #Trained:111 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.46% Speed(reviews/sec):201.2 #Correct:0 #Trained:112 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.46% Speed(reviews/sec):201.2 #Correct:0 #Trained:113 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):201.2 #Correct:0 #Trained:114 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):201.2 #Correct:0 #Trained:115 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):201.6 #Correct:0 #Trained:116 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.48% Speed(reviews/sec):201.6 #Correct:0 #Trained:117 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.48% Speed(reviews/sec):201.9 #Correct:0 #Trained:118 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.49% Speed(reviews/sec):202.2 #Correct:0 #Trained:119 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.49% Speed(reviews/sec):202.6 #Correct:0 #Trained:120 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.5% Speed(reviews/sec):202.6 #Correct:0 #Trained:121 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.50% Speed(reviews/sec):202.9 #Correct:0 #Trained:122 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.50% Speed(reviews/sec):202.9 #Correct:0 #Trained:123 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.51% Speed(reviews/sec):203.2 #Correct:0 #Trained:124 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.51% Speed(reviews/sec):203.5 #Correct:0 #Trained:125 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):203.5 #Correct:0 #Trained:126 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):203.8 #Correct:0 #Trained:127 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):203.7 #Correct:0 #Trained:128 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.53% Speed(reviews/sec):204.0 #Correct:0 #Trained:129 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.53% Speed(reviews/sec):204.3 #Correct:0 #Trained:130 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.54% Speed(reviews/sec):204.3 #Correct:0 #Trained:131 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.54% Speed(reviews/sec):204.6 #Correct:0 #Trained:132 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):204.9 #Correct:0 #Trained:133 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):205.1 #Correct:0 #Trained:134 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):205.1 #Correct:0 #Trained:135 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.56% Speed(reviews/sec):205.4 #Correct:0 #Trained:136 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.56% Speed(reviews/sec):205.4 #Correct:0 #Trained:137 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):205.6 #Correct:0 #Trained:138 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):205.9 #Correct:0 #Trained:139 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):205.8 #Correct:0 #Trained:140 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.58% Speed(reviews/sec):205.8 #Correct:0 #Trained:141 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.58% Speed(reviews/sec):206.1 #Correct:0 #Trained:142 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.59% Speed(reviews/sec):206.0 #Correct:0 #Trained:143 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.59% Speed(reviews/sec):205.7 #Correct:0 #Trained:144 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.6% Speed(reviews/sec):205.7 #Correct:0 #Trained:145 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.60% Speed(reviews/sec):205.6 #Correct:0 #Trained:146 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.60% Speed(reviews/sec):205.3 #Correct:0 #Trained:147 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.61% Speed(reviews/sec):205.3 #Correct:0 #Trained:148 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.61% Speed(reviews/sec):205.2 #Correct:0 #Trained:149 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):204.9 #Correct:0 #Trained:150 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):204.3 #Correct:0 #Trained:151 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):204.3 #Correct:0 #Trained:152 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.63% Speed(reviews/sec):204.0 #Correct:0 #Trained:153 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.63% Speed(reviews/sec):203.7 #Correct:0 #Trained:154 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.64% Speed(reviews/sec):203.7 #Correct:0 #Trained:155 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.64% Speed(reviews/sec):203.7 #Correct:0 #Trained:156 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):203.6 #Correct:0 #Trained:157 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):203.4 #Correct:0 #Trained:158 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):203.3 #Correct:0 #Trained:159 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.66% Speed(reviews/sec):203.1 #Correct:0 #Trained:160 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.66% Speed(reviews/sec):203.1 #Correct:0 #Trained:161 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):203.0 #Correct:0 #Trained:162 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):202.8 #Correct:0 #Trained:163 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):202.8 #Correct:0 #Trained:164 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.68% Speed(reviews/sec):202.7 #Correct:0 #Trained:165 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.68% Speed(reviews/sec):202.7 #Correct:0 #Trained:166 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.69% Speed(reviews/sec):202.7 #Correct:0 #Trained:167 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.69% Speed(reviews/sec):202.5 #Correct:0 #Trained:168 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.7% Speed(reviews/sec):202.7 #Correct:0 #Trained:169 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.70% Speed(reviews/sec):202.4 #Correct:0 #Trained:170 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.70% Speed(reviews/sec):202.7 #Correct:0 #Trained:171 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.71% Speed(reviews/sec):202.6 #Correct:0 #Trained:172 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.71% Speed(reviews/sec):202.6 #Correct:0 #Trained:173 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):202.6 #Correct:0 #Trained:174 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):202.6 #Correct:0 #Trained:175 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):202.6 #Correct:0 #Trained:176 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.73% Speed(reviews/sec):202.6 #Correct:0 #Trained:177 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.73% Speed(reviews/sec):202.3 #Correct:0 #Trained:178 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.74% Speed(reviews/sec):202.5 #Correct:0 #Trained:179 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.74% Speed(reviews/sec):202.5 #Correct:0 #Trained:180 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):202.5 #Correct:0 #Trained:181 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):202.5 #Correct:0 #Trained:182 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):202.5 #Correct:0 #Trained:183 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.76% Speed(reviews/sec):202.5 #Correct:0 #Trained:184 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.76% Speed(reviews/sec):202.3 #Correct:0 #Trained:185 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):202.3 #Correct:0 #Trained:186 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):202.5 #Correct:0 #Trained:187 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):202.2 #Correct:0 #Trained:188 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.78% Speed(reviews/sec):202.2 #Correct:0 #Trained:189 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.78% Speed(reviews/sec):202.2 #Correct:0 #Trained:190 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.79% Speed(reviews/sec):202.4 #Correct:0 #Trained:191 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.79% Speed(reviews/sec):202.2 #Correct:0 #Trained:192 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.8% Speed(reviews/sec):202.4 #Correct:0 #Trained:193 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.80% Speed(reviews/sec):202.4 #Correct:0 #Trained:194 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.80% Speed(reviews/sec):202.6 #Correct:0 #Trained:195 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.81% Speed(reviews/sec):202.6 #Correct:0 #Trained:196 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.81% Speed(reviews/sec):202.6 #Correct:0 #Trained:197 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):202.6 #Correct:0 #Trained:198 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):202.6 #Correct:0 #Trained:199 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):202.5 #Correct:0 #Trained:200 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.83% Speed(reviews/sec):202.7 #Correct:0 #Trained:201 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.83% Speed(reviews/sec):202.7 #Correct:0 #Trained:202 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.84% Speed(reviews/sec):202.7 #Correct:0 #Trained:203 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.84% Speed(reviews/sec):202.7 #Correct:0 #Trained:204 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):202.9 #Correct:0 #Trained:205 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):202.9 #Correct:0 #Trained:206 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):202.9 #Correct:0 #Trained:207 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.86% Speed(reviews/sec):203.1 #Correct:0 #Trained:208 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.86% Speed(reviews/sec):203.0 #Correct:0 #Trained:209 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):203.0 #Correct:0 #Trained:210 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):203.2 #Correct:0 #Trained:211 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):203.0 #Correct:0 #Trained:212 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.88% Speed(reviews/sec):202.6 #Correct:0 #Trained:213 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.88% Speed(reviews/sec):202.8 #Correct:0 #Trained:214 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.89% Speed(reviews/sec):202.8 #Correct:0 #Trained:215 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.89% Speed(reviews/sec):202.6 #Correct:0 #Trained:216 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.9% Speed(reviews/sec):202.8 #Correct:0 #Trained:217 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.90% Speed(reviews/sec):202.9 #Correct:0 #Trained:218 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.90% Speed(reviews/sec):202.9 #Correct:0 #Trained:219 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.91% Speed(reviews/sec):203.1 #Correct:0 #Trained:220 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.91% Speed(reviews/sec):203.1 #Correct:0 #Trained:221 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):202.9 #Correct:0 #Trained:222 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):203.1 #Correct:0 #Trained:223 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):203.2 #Correct:0 #Trained:224 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.93% Speed(reviews/sec):203.2 #Correct:0 #Trained:225 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.93% Speed(reviews/sec):203.2 #Correct:0 #Trained:226 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.94% Speed(reviews/sec):203.2 #Correct:0 #Trained:227 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.94% Speed(reviews/sec):203.2 #Correct:0 #Trained:228 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):203.2 #Correct:0 #Trained:229 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):203.2 #Correct:0 #Trained:230 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):203.2 #Correct:0 #Trained:231 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.96% Speed(reviews/sec):203.3 #Correct:0 #Trained:232 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.96% Speed(reviews/sec):203.5 #Correct:0 #Trained:233 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):203.5 #Correct:0 #Trained:234 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):203.6 #Correct:0 #Trained:235 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):203.8 #Correct:0 #Trained:236 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.98% Speed(reviews/sec):203.8 #Correct:0 #Trained:237 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.98% Speed(reviews/sec):203.9 #Correct:0 #Trained:238 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.99% Speed(reviews/sec):204.1 #Correct:0 #Trained:239 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:0.99% Speed(reviews/sec):204.1 #Correct:0 #Trained:240 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.0% Speed(reviews/sec):204.3 #Correct:0 #Trained:241 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.00% Speed(reviews/sec):204.2 #Correct:0 #Trained:242 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.00% Speed(reviews/sec):204.4 #Correct:0 #Trained:243 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.01% Speed(reviews/sec):204.4 #Correct:0 #Trained:244 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.01% Speed(reviews/sec):204.5 #Correct:0 #Trained:245 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):204.5 #Correct:0 #Trained:246 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):204.7 #Correct:0 #Trained:247 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):204.8 #Correct:0 #Trained:248 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.03% Speed(reviews/sec):204.8 #Correct:0 #Trained:249 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.03% Speed(reviews/sec):204.9 #Correct:0 #Trained:250 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.04% Speed(reviews/sec):205.1 #Correct:0 #Trained:251 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.04% Speed(reviews/sec):205.1 #Correct:0 #Trained:252 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):205.1 #Correct:0 #Trained:253 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):205.2 #Correct:0 #Trained:254 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):205.4 #Correct:0 #Trained:255 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.06% Speed(reviews/sec):205.2 #Correct:0 #Trained:256 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.06% Speed(reviews/sec):205.1 #Correct:0 #Trained:257 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):205.3 #Correct:0 #Trained:258 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):205.3 #Correct:0 #Trained:259 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):205.3 #Correct:0 #Trained:260 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.08% Speed(reviews/sec):205.2 #Correct:0 #Trained:261 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.08% Speed(reviews/sec):205.2 #Correct:0 #Trained:262 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.09% Speed(reviews/sec):205.4 #Correct:0 #Trained:263 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.09% Speed(reviews/sec):205.3 #Correct:0 #Trained:264 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.1% Speed(reviews/sec):205.3 #Correct:0 #Trained:265 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.10% Speed(reviews/sec):205.5 #Correct:0 #Trained:266 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.10% Speed(reviews/sec):205.4 #Correct:0 #Trained:267 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.11% Speed(reviews/sec):205.4 #Correct:0 #Trained:268 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.11% Speed(reviews/sec):205.4 #Correct:0 #Trained:269 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):205.4 #Correct:0 #Trained:270 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):205.5 #Correct:0 #Trained:271 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):205.5 #Correct:0 #Trained:272 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.13% Speed(reviews/sec):205.5 #Correct:0 #Trained:273 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.13% Speed(reviews/sec):205.5 #Correct:0 #Trained:274 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.14% Speed(reviews/sec):205.5 #Correct:0 #Trained:275 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.14% Speed(reviews/sec):205.4 #Correct:0 #Trained:276 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):205.4 #Correct:0 #Trained:277 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):205.5 #Correct:0 #Trained:278 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):205.5 #Correct:0 #Trained:279 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.16% Speed(reviews/sec):205.5 #Correct:0 #Trained:280 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.16% Speed(reviews/sec):205.5 #Correct:0 #Trained:281 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):205.6 #Correct:0 #Trained:282 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):205.6 #Correct:0 #Trained:283 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):205.6 #Correct:0 #Trained:284 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.18% Speed(reviews/sec):205.7 #Correct:0 #Trained:285 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.18% Speed(reviews/sec):205.7 #Correct:0 #Trained:286 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.19% Speed(reviews/sec):205.7 #Correct:0 #Trained:287 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.19% Speed(reviews/sec):205.8 #Correct:0 #Trained:288 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.2% Speed(reviews/sec):205.9 #Correct:0 #Trained:289 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.20% Speed(reviews/sec):205.9 #Correct:0 #Trained:290 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.20% Speed(reviews/sec):205.9 #Correct:0 #Trained:291 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.21% Speed(reviews/sec):206.0 #Correct:0 #Trained:292 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.21% Speed(reviews/sec):206.1 #Correct:0 #Trained:293 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):206.1 #Correct:0 #Trained:294 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):206.1 #Correct:0 #Trained:295 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):206.1 #Correct:0 #Trained:296 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.23% Speed(reviews/sec):206.2 #Correct:0 #Trained:297 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.23% Speed(reviews/sec):206.3 #Correct:0 #Trained:298 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.24% Speed(reviews/sec):206.3 #Correct:0 #Trained:299 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.24% Speed(reviews/sec):206.4 #Correct:0 #Trained:300 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):206.4 #Correct:0 #Trained:301 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):206.5 #Correct:0 #Trained:302 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):206.5 #Correct:0 #Trained:303 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.26% Speed(reviews/sec):206.5 #Correct:0 #Trained:304 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.26% Speed(reviews/sec):206.5 #Correct:0 #Trained:305 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):206.5 #Correct:0 #Trained:306 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):206.4 #Correct:0 #Trained:307 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):206.6 #Correct:0 #Trained:308 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.28% Speed(reviews/sec):206.7 #Correct:0 #Trained:309 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.28% Speed(reviews/sec):206.7 #Correct:0 #Trained:310 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.29% Speed(reviews/sec):206.6 #Correct:0 #Trained:311 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.29% Speed(reviews/sec):206.8 #Correct:0 #Trained:312 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.3% Speed(reviews/sec):206.7 #Correct:0 #Trained:313 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.30% Speed(reviews/sec):206.8 #Correct:0 #Trained:314 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.30% Speed(reviews/sec):206.8 #Correct:0 #Trained:315 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.31% Speed(reviews/sec):206.8 #Correct:0 #Trained:316 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.31% Speed(reviews/sec):206.8 #Correct:0 #Trained:317 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):206.8 #Correct:0 #Trained:318 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):206.9 #Correct:0 #Trained:319 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):206.9 #Correct:0 #Trained:320 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.33% Speed(reviews/sec):207.0 #Correct:0 #Trained:321 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.33% Speed(reviews/sec):207.1 #Correct:0 #Trained:322 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.34% Speed(reviews/sec):207.1 #Correct:0 #Trained:323 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.34% Speed(reviews/sec):207.0 #Correct:0 #Trained:324 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):207.1 #Correct:0 #Trained:325 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):207.1 #Correct:0 #Trained:326 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):207.1 #Correct:0 #Trained:327 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.36% Speed(reviews/sec):207.2 #Correct:0 #Trained:328 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.36% Speed(reviews/sec):207.2 #Correct:0 #Trained:329 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):207.0 #Correct:0 #Trained:330 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):207.2 #Correct:0 #Trained:331 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):207.1 #Correct:0 #Trained:332 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.38% Speed(reviews/sec):207.1 #Correct:0 #Trained:333 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.38% Speed(reviews/sec):207.2 #Correct:0 #Trained:334 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.39% Speed(reviews/sec):207.2 #Correct:0 #Trained:335 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.39% Speed(reviews/sec):207.2 #Correct:0 #Trained:336 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.4% Speed(reviews/sec):207.2 #Correct:0 #Trained:337 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.40% Speed(reviews/sec):207.1 #Correct:0 #Trained:338 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.40% Speed(reviews/sec):207.2 #Correct:0 #Trained:339 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.41% Speed(reviews/sec):207.2 #Correct:0 #Trained:340 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.41% Speed(reviews/sec):207.2 #Correct:0 #Trained:341 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):207.3 #Correct:0 #Trained:342 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):207.2 #Correct:0 #Trained:343 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):207.3 #Correct:0 #Trained:344 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.43% Speed(reviews/sec):207.1 #Correct:0 #Trained:345 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.43% Speed(reviews/sec):207.0 #Correct:0 #Trained:346 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.44% Speed(reviews/sec):207.1 #Correct:0 #Trained:347 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.44% Speed(reviews/sec):206.9 #Correct:0 #Trained:348 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):206.8 #Correct:0 #Trained:349 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):206.8 #Correct:0 #Trained:350 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):206.8 #Correct:0 #Trained:351 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.46% Speed(reviews/sec):206.6 #Correct:0 #Trained:352 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.46% Speed(reviews/sec):206.5 #Correct:0 #Trained:353 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):206.3 #Correct:0 #Trained:354 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):206.3 #Correct:0 #Trained:355 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):206.3 #Correct:0 #Trained:356 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.48% Speed(reviews/sec):206.3 #Correct:0 #Trained:357 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.48% Speed(reviews/sec):206.3 #Correct:0 #Trained:358 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.49% Speed(reviews/sec):206.1 #Correct:0 #Trained:359 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.49% Speed(reviews/sec):206.1 #Correct:0 #Trained:360 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.5% Speed(reviews/sec):206.1 #Correct:0 #Trained:361 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.50% Speed(reviews/sec):206.2 #Correct:0 #Trained:362 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.50% Speed(reviews/sec):206.2 #Correct:0 #Trained:363 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.51% Speed(reviews/sec):206.2 #Correct:0 #Trained:364 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.51% Speed(reviews/sec):206.2 #Correct:0 #Trained:365 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):206.1 #Correct:0 #Trained:366 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):206.2 #Correct:0 #Trained:367 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):206.2 #Correct:0 #Trained:368 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.53% Speed(reviews/sec):206.2 #Correct:0 #Trained:369 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.53% Speed(reviews/sec):206.1 #Correct:0 #Trained:370 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.54% Speed(reviews/sec):206.1 #Correct:0 #Trained:371 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.54% Speed(reviews/sec):206.1 #Correct:0 #Trained:372 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):206.0 #Correct:0 #Trained:373 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):206.1 #Correct:0 #Trained:374 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):206.1 #Correct:0 #Trained:375 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.56% Speed(reviews/sec):206.2 #Correct:0 #Trained:376 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.56% Speed(reviews/sec):206.3 #Correct:0 #Trained:377 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):206.4 #Correct:0 #Trained:378 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):206.5 #Correct:0 #Trained:379 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):206.5 #Correct:0 #Trained:380 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.58% Speed(reviews/sec):206.5 #Correct:0 #Trained:381 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.58% Speed(reviews/sec):206.6 #Correct:0 #Trained:382 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.59% Speed(reviews/sec):206.7 #Correct:0 #Trained:383 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.59% Speed(reviews/sec):206.6 #Correct:0 #Trained:384 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.6% Speed(reviews/sec):206.6 #Correct:0 #Trained:385 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.60% Speed(reviews/sec):206.6 #Correct:0 #Trained:386 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.60% Speed(reviews/sec):206.6 #Correct:0 #Trained:387 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.61% Speed(reviews/sec):206.6 #Correct:0 #Trained:388 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.61% Speed(reviews/sec):206.6 #Correct:0 #Trained:389 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.62% Speed(reviews/sec):206.6 #Correct:0 #Trained:390 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.62% Speed(reviews/sec):206.6 #Correct:0 #Trained:391 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.62% Speed(reviews/sec):206.7 #Correct:0 #Trained:392 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.63% Speed(reviews/sec):206.7 #Correct:0 #Trained:393 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:1.63% Speed(reviews/sec):206.8 #Correct:0 #Trained:394 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# ...
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23872 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23873 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23874 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23875 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23876 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23877 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23878 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23879 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.4% Speed(reviews/sec):211.2 #Correct:0 #Trained:23880 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23881 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23882 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23883 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23884 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23885 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23886 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23887 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23888 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23889 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23890 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23891 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23892 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23893 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23894 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23895 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23896 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23897 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23898 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23899 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23900 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23901 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23902 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23903 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.5% Speed(reviews/sec):211.2 #Correct:0 #Trained:23904 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23905 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23906 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23907 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23908 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23909 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23910 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23911 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23912 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23913 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23914 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23915 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23916 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23917 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23918 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23919 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23920 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23921 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.3 #Correct:0 #Trained:23922 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23923 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.3 #Correct:0 #Trained:23924 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23925 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23926 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23927 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.6% Speed(reviews/sec):211.2 #Correct:0 #Trained:23928 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23929 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23930 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23931 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23932 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23933 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23934 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23935 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23936 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23937 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23938 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23939 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23940 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23941 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.2 #Correct:0 #Trained:23942 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23943 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23944 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23945 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23946 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23947 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23948 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23949 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23950 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23951 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.7% Speed(reviews/sec):211.3 #Correct:0 #Trained:23952 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23953 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23954 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23955 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23956 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23957 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23958 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23959 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23960 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23961 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23962 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23963 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23964 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23965 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23966 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23967 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23968 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23969 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23970 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23971 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23972 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23973 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23974 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23975 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.8% Speed(reviews/sec):211.3 #Correct:0 #Trained:23976 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23977 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23978 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23979 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23980 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23981 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23982 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23983 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23984 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23985 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23986 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23987 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23988 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23989 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23990 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23991 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23992 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23993 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23994 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23995 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23996 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23997 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23998 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:23999 Training Accuracy:0.0%The shape of layer_0 is  (1, 74074)
# Progress:99.9% Speed(reviews/sec):211.3 #Correct:0 #Trained:24000 Training Accuracy:0.0%

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)

# %%
mlp.train(reviews[:-1000], labels[:-1000])
# Out:
# The shape of layer_0 is  (1, 74074)
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# The shape of layer_0 is  (1, 74074)
# Progress:0.00% Speed(reviews/sec):77.12 #Correct:1 #Trained:2 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.00% Speed(reviews/sec):105.5 #Correct:2 #Trained:3 Training Accuracy:66.6%The shape of layer_0 is  (1, 74074)
# Progress:0.01% Speed(reviews/sec):120.3 #Correct:2 #Trained:4 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.01% Speed(reviews/sec):133.6 #Correct:3 #Trained:5 Training Accuracy:60.0%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):147.3 #Correct:3 #Trained:6 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):154.1 #Correct:4 #Trained:7 Training Accuracy:57.1%The shape of layer_0 is  (1, 74074)
# Progress:0.02% Speed(reviews/sec):163.1 #Correct:4 #Trained:8 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.03% Speed(reviews/sec):167.0 #Correct:5 #Trained:9 Training Accuracy:55.5%The shape of layer_0 is  (1, 74074)
# Progress:0.03% Speed(reviews/sec):170.2 #Correct:5 #Trained:10 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.04% Speed(reviews/sec):172.8 #Correct:6 #Trained:11 Training Accuracy:54.5%The shape of layer_0 is  (1, 74074)
# Progress:0.04% Speed(reviews/sec):177.7 #Correct:6 #Trained:12 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):182.1 #Correct:7 #Trained:13 Training Accuracy:53.8%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):183.4 #Correct:7 #Trained:14 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.05% Speed(reviews/sec):184.6 #Correct:8 #Trained:15 Training Accuracy:53.3%The shape of layer_0 is  (1, 74074)
# Progress:0.06% Speed(reviews/sec):187.9 #Correct:8 #Trained:16 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.06% Speed(reviews/sec):188.7 #Correct:9 #Trained:17 Training Accuracy:52.9%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):191.4 #Correct:9 #Trained:18 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):194.0 #Correct:10 #Trained:19 Training Accuracy:52.6%The shape of layer_0 is  (1, 74074)
# Progress:0.07% Speed(reviews/sec):196.3 #Correct:10 #Trained:20 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.08% Speed(reviews/sec):196.5 #Correct:11 #Trained:21 Training Accuracy:52.3%The shape of layer_0 is  (1, 74074)
# Progress:0.08% Speed(reviews/sec):198.6 #Correct:11 #Trained:22 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.09% Speed(reviews/sec):198.6 #Correct:12 #Trained:23 Training Accuracy:52.1%The shape of layer_0 is  (1, 74074)
# Progress:0.09% Speed(reviews/sec):200.4 #Correct:12 #Trained:24 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.1% Speed(reviews/sec):200.5 #Correct:13 #Trained:25 Training Accuracy:52.0%The shape of layer_0 is  (1, 74074)
# Progress:0.10% Speed(reviews/sec):202.1 #Correct:13 #Trained:26 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.10% Speed(reviews/sec):203.6 #Correct:14 #Trained:27 Training Accuracy:51.8%The shape of layer_0 is  (1, 74074)
# Progress:0.11% Speed(reviews/sec):203.5 #Correct:14 #Trained:28 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.11% Speed(reviews/sec):204.9 #Correct:15 #Trained:29 Training Accuracy:51.7%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):206.2 #Correct:15 #Trained:30 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):207.4 #Correct:16 #Trained:31 Training Accuracy:51.6%The shape of layer_0 is  (1, 74074)
# Progress:0.12% Speed(reviews/sec):208.5 #Correct:16 #Trained:32 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.13% Speed(reviews/sec):209.6 #Correct:17 #Trained:33 Training Accuracy:51.5%The shape of layer_0 is  (1, 74074)
# Progress:0.13% Speed(reviews/sec):209.4 #Correct:17 #Trained:34 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.14% Speed(reviews/sec):210.4 #Correct:18 #Trained:35 Training Accuracy:51.4%The shape of layer_0 is  (1, 74074)
# Progress:0.14% Speed(reviews/sec):211.3 #Correct:18 #Trained:36 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):212.3 #Correct:19 #Trained:37 Training Accuracy:51.3%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):213.1 #Correct:19 #Trained:38 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.15% Speed(reviews/sec):214.0 #Correct:20 #Trained:39 Training Accuracy:51.2%The shape of layer_0 is  (1, 74074)
# Progress:0.16% Speed(reviews/sec):213.6 #Correct:20 #Trained:40 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.16% Speed(reviews/sec):213.3 #Correct:21 #Trained:41 Training Accuracy:51.2%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):214.0 #Correct:21 #Trained:42 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):212.6 #Correct:22 #Trained:43 Training Accuracy:51.1%The shape of layer_0 is  (1, 74074)
# Progress:0.17% Speed(reviews/sec):210.3 #Correct:22 #Trained:44 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.18% Speed(reviews/sec):211.0 #Correct:23 #Trained:45 Training Accuracy:51.1%The shape of layer_0 is  (1, 74074)
# Progress:0.18% Speed(reviews/sec):210.8 #Correct:23 #Trained:46 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.19% Speed(reviews/sec):211.5 #Correct:24 #Trained:47 Training Accuracy:51.0%The shape of layer_0 is  (1, 74074)
# Progress:0.19% Speed(reviews/sec):212.2 #Correct:24 #Trained:48 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.2% Speed(reviews/sec):212.9 #Correct:25 #Trained:49 Training Accuracy:51.0%The shape of layer_0 is  (1, 74074)
# Progress:0.20% Speed(reviews/sec):212.6 #Correct:25 #Trained:50 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.20% Speed(reviews/sec):213.3 #Correct:26 #Trained:51 Training Accuracy:50.9%The shape of layer_0 is  (1, 74074)
# Progress:0.21% Speed(reviews/sec):213.0 #Correct:26 #Trained:52 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.21% Speed(reviews/sec):213.6 #Correct:27 #Trained:53 Training Accuracy:50.9%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):214.2 #Correct:27 #Trained:54 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):213.9 #Correct:28 #Trained:55 Training Accuracy:50.9%The shape of layer_0 is  (1, 74074)
# Progress:0.22% Speed(reviews/sec):214.5 #Correct:28 #Trained:56 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.23% Speed(reviews/sec):215.1 #Correct:29 #Trained:57 Training Accuracy:50.8%The shape of layer_0 is  (1, 74074)
# Progress:0.23% Speed(reviews/sec):214.8 #Correct:29 #Trained:58 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.24% Speed(reviews/sec):215.3 #Correct:30 #Trained:59 Training Accuracy:50.8%The shape of layer_0 is  (1, 74074)
# Progress:0.24% Speed(reviews/sec):215.8 #Correct:30 #Trained:60 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):215.6 #Correct:31 #Trained:61 Training Accuracy:50.8%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):216.1 #Correct:31 #Trained:62 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.25% Speed(reviews/sec):216.5 #Correct:32 #Trained:63 Training Accuracy:50.7%The shape of layer_0 is  (1, 74074)
# Progress:0.26% Speed(reviews/sec):217.0 #Correct:32 #Trained:64 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.26% Speed(reviews/sec):217.5 #Correct:33 #Trained:65 Training Accuracy:50.7%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):217.2 #Correct:33 #Trained:66 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):217.6 #Correct:34 #Trained:67 Training Accuracy:50.7%The shape of layer_0 is  (1, 74074)
# Progress:0.27% Speed(reviews/sec):218.1 #Correct:34 #Trained:68 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.28% Speed(reviews/sec):218.5 #Correct:35 #Trained:69 Training Accuracy:50.7%The shape of layer_0 is  (1, 74074)
# Progress:0.28% Speed(reviews/sec):218.2 #Correct:35 #Trained:70 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.29% Speed(reviews/sec):218.6 #Correct:36 #Trained:71 Training Accuracy:50.7%The shape of layer_0 is  (1, 74074)
# Progress:0.29% Speed(reviews/sec):218.3 #Correct:36 #Trained:72 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.3% Speed(reviews/sec):218.7 #Correct:37 #Trained:73 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.30% Speed(reviews/sec):219.1 #Correct:37 #Trained:74 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.30% Speed(reviews/sec):218.8 #Correct:38 #Trained:75 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.31% Speed(reviews/sec):219.2 #Correct:38 #Trained:76 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.31% Speed(reviews/sec):218.9 #Correct:39 #Trained:77 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):219.3 #Correct:39 #Trained:78 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):219.6 #Correct:40 #Trained:79 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.32% Speed(reviews/sec):220.1 #Correct:40 #Trained:80 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.33% Speed(reviews/sec):219.8 #Correct:41 #Trained:81 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.33% Speed(reviews/sec):220.1 #Correct:41 #Trained:82 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.34% Speed(reviews/sec):219.9 #Correct:42 #Trained:83 Training Accuracy:50.6%The shape of layer_0 is  (1, 74074)
# Progress:0.34% Speed(reviews/sec):219.8 #Correct:42 #Trained:84 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):219.5 #Correct:43 #Trained:85 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):219.3 #Correct:43 #Trained:86 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.35% Speed(reviews/sec):219.0 #Correct:44 #Trained:87 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.36% Speed(reviews/sec):218.8 #Correct:44 #Trained:88 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.36% Speed(reviews/sec):218.6 #Correct:45 #Trained:89 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):218.9 #Correct:45 #Trained:90 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):218.7 #Correct:46 #Trained:91 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.37% Speed(reviews/sec):218.4 #Correct:46 #Trained:92 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.38% Speed(reviews/sec):218.2 #Correct:47 #Trained:93 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.38% Speed(reviews/sec):218.5 #Correct:47 #Trained:94 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.39% Speed(reviews/sec):218.3 #Correct:48 #Trained:95 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.39% Speed(reviews/sec):218.6 #Correct:48 #Trained:96 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.4% Speed(reviews/sec):218.9 #Correct:49 #Trained:97 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.40% Speed(reviews/sec):218.7 #Correct:49 #Trained:98 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.40% Speed(reviews/sec):218.5 #Correct:50 #Trained:99 Training Accuracy:50.5%The shape of layer_0 is  (1, 74074)
# Progress:0.41% Speed(reviews/sec):218.8 #Correct:50 #Trained:100 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.41% Speed(reviews/sec):218.6 #Correct:51 #Trained:101 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):218.8 #Correct:51 #Trained:102 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):219.1 #Correct:52 #Trained:103 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.42% Speed(reviews/sec):219.4 #Correct:52 #Trained:104 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.43% Speed(reviews/sec):219.6 #Correct:53 #Trained:105 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.43% Speed(reviews/sec):219.5 #Correct:53 #Trained:106 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.44% Speed(reviews/sec):219.7 #Correct:54 #Trained:107 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.44% Speed(reviews/sec):219.5 #Correct:54 #Trained:108 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):219.8 #Correct:55 #Trained:109 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):220.0 #Correct:55 #Trained:110 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.45% Speed(reviews/sec):219.8 #Correct:56 #Trained:111 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.46% Speed(reviews/sec):220.1 #Correct:56 #Trained:112 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.46% Speed(reviews/sec):219.9 #Correct:57 #Trained:113 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):220.1 #Correct:57 #Trained:114 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):220.3 #Correct:58 #Trained:115 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.47% Speed(reviews/sec):220.2 #Correct:58 #Trained:116 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.48% Speed(reviews/sec):220.4 #Correct:59 #Trained:117 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.48% Speed(reviews/sec):220.6 #Correct:59 #Trained:118 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.49% Speed(reviews/sec):220.9 #Correct:60 #Trained:119 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.49% Speed(reviews/sec):221.1 #Correct:60 #Trained:120 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.5% Speed(reviews/sec):220.9 #Correct:61 #Trained:121 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.50% Speed(reviews/sec):221.1 #Correct:61 #Trained:122 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.50% Speed(reviews/sec):221.3 #Correct:62 #Trained:123 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.51% Speed(reviews/sec):221.5 #Correct:62 #Trained:124 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.51% Speed(reviews/sec):221.3 #Correct:63 #Trained:125 Training Accuracy:50.4%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):221.2 #Correct:63 #Trained:126 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):221.0 #Correct:64 #Trained:127 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.52% Speed(reviews/sec):220.4 #Correct:64 #Trained:128 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.53% Speed(reviews/sec):220.2 #Correct:65 #Trained:129 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.53% Speed(reviews/sec):219.7 #Correct:65 #Trained:130 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.54% Speed(reviews/sec):219.9 #Correct:66 #Trained:131 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.54% Speed(reviews/sec):219.4 #Correct:66 #Trained:132 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):219.2 #Correct:67 #Trained:133 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):219.4 #Correct:67 #Trained:134 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.55% Speed(reviews/sec):218.9 #Correct:68 #Trained:135 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.56% Speed(reviews/sec):218.7 #Correct:68 #Trained:136 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.56% Speed(reviews/sec):219.0 #Correct:69 #Trained:137 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):219.2 #Correct:69 #Trained:138 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):219.4 #Correct:70 #Trained:139 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.57% Speed(reviews/sec):219.6 #Correct:70 #Trained:140 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.58% Speed(reviews/sec):219.4 #Correct:71 #Trained:141 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.58% Speed(reviews/sec):219.6 #Correct:71 #Trained:142 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.59% Speed(reviews/sec):219.8 #Correct:72 #Trained:143 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.59% Speed(reviews/sec):220.0 #Correct:72 #Trained:144 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.6% Speed(reviews/sec):220.2 #Correct:73 #Trained:145 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.60% Speed(reviews/sec):220.4 #Correct:73 #Trained:146 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.60% Speed(reviews/sec):220.5 #Correct:74 #Trained:147 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.61% Speed(reviews/sec):220.4 #Correct:74 #Trained:148 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.61% Speed(reviews/sec):220.6 #Correct:75 #Trained:149 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):220.7 #Correct:75 #Trained:150 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):220.9 #Correct:76 #Trained:151 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.62% Speed(reviews/sec):221.1 #Correct:76 #Trained:152 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.63% Speed(reviews/sec):221.0 #Correct:77 #Trained:153 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.63% Speed(reviews/sec):221.1 #Correct:77 #Trained:154 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.64% Speed(reviews/sec):221.3 #Correct:78 #Trained:155 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.64% Speed(reviews/sec):221.1 #Correct:78 #Trained:156 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):221.3 #Correct:79 #Trained:157 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):221.5 #Correct:79 #Trained:158 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.65% Speed(reviews/sec):221.6 #Correct:80 #Trained:159 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.66% Speed(reviews/sec):221.5 #Correct:80 #Trained:160 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.66% Speed(reviews/sec):221.6 #Correct:81 #Trained:161 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):221.8 #Correct:81 #Trained:162 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):221.7 #Correct:82 #Trained:163 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.67% Speed(reviews/sec):221.8 #Correct:82 #Trained:164 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.68% Speed(reviews/sec):222.0 #Correct:83 #Trained:165 Training Accuracy:50.3%The shape of layer_0 is  (1, 74074)
# Progress:0.68% Speed(reviews/sec):222.1 #Correct:83 #Trained:166 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.69% Speed(reviews/sec):222.0 #Correct:84 #Trained:167 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.69% Speed(reviews/sec):221.8 #Correct:84 #Trained:168 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.7% Speed(reviews/sec):221.7 #Correct:85 #Trained:169 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.70% Speed(reviews/sec):221.6 #Correct:85 #Trained:170 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.70% Speed(reviews/sec):221.7 #Correct:86 #Trained:171 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.71% Speed(reviews/sec):221.6 #Correct:86 #Trained:172 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.71% Speed(reviews/sec):221.4 #Correct:87 #Trained:173 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):221.6 #Correct:87 #Trained:174 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):221.7 #Correct:88 #Trained:175 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.72% Speed(reviews/sec):221.6 #Correct:88 #Trained:176 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.73% Speed(reviews/sec):221.5 #Correct:89 #Trained:177 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.73% Speed(reviews/sec):221.6 #Correct:89 #Trained:178 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.74% Speed(reviews/sec):221.8 #Correct:90 #Trained:179 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.74% Speed(reviews/sec):221.6 #Correct:90 #Trained:180 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):221.8 #Correct:91 #Trained:181 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):221.9 #Correct:91 #Trained:182 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.75% Speed(reviews/sec):221.8 #Correct:92 #Trained:183 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.76% Speed(reviews/sec):221.7 #Correct:92 #Trained:184 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.76% Speed(reviews/sec):221.5 #Correct:93 #Trained:185 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):221.7 #Correct:93 #Trained:186 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):221.8 #Correct:94 #Trained:187 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.77% Speed(reviews/sec):221.9 #Correct:94 #Trained:188 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.78% Speed(reviews/sec):222.1 #Correct:95 #Trained:189 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.78% Speed(reviews/sec):222.2 #Correct:95 #Trained:190 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.79% Speed(reviews/sec):222.1 #Correct:96 #Trained:191 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.79% Speed(reviews/sec):222.2 #Correct:96 #Trained:192 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.8% Speed(reviews/sec):222.4 #Correct:97 #Trained:193 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.80% Speed(reviews/sec):222.5 #Correct:97 #Trained:194 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.80% Speed(reviews/sec):222.6 #Correct:98 #Trained:195 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.81% Speed(reviews/sec):222.7 #Correct:98 #Trained:196 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.81% Speed(reviews/sec):222.9 #Correct:99 #Trained:197 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):222.7 #Correct:99 #Trained:198 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):222.9 #Correct:100 #Trained:199 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.82% Speed(reviews/sec):223.0 #Correct:100 #Trained:200 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.83% Speed(reviews/sec):223.1 #Correct:101 #Trained:201 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.83% Speed(reviews/sec):223.2 #Correct:101 #Trained:202 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.84% Speed(reviews/sec):223.1 #Correct:102 #Trained:203 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.84% Speed(reviews/sec):223.2 #Correct:102 #Trained:204 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):223.3 #Correct:103 #Trained:205 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):223.5 #Correct:103 #Trained:206 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.85% Speed(reviews/sec):223.6 #Correct:104 #Trained:207 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.86% Speed(reviews/sec):223.5 #Correct:104 #Trained:208 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.86% Speed(reviews/sec):223.6 #Correct:105 #Trained:209 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):223.5 #Correct:105 #Trained:210 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):223.3 #Correct:106 #Trained:211 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.87% Speed(reviews/sec):223.2 #Correct:106 #Trained:212 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.88% Speed(reviews/sec):223.1 #Correct:107 #Trained:213 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.88% Speed(reviews/sec):223.0 #Correct:107 #Trained:214 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.89% Speed(reviews/sec):223.1 #Correct:108 #Trained:215 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.89% Speed(reviews/sec):223.0 #Correct:108 #Trained:216 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.9% Speed(reviews/sec):223.1 #Correct:109 #Trained:217 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.90% Speed(reviews/sec):223.2 #Correct:109 #Trained:218 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.90% Speed(reviews/sec):223.1 #Correct:110 #Trained:219 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.91% Speed(reviews/sec):223.2 #Correct:110 #Trained:220 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.91% Speed(reviews/sec):223.3 #Correct:111 #Trained:221 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):223.2 #Correct:111 #Trained:222 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):223.3 #Correct:112 #Trained:223 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.92% Speed(reviews/sec):223.4 #Correct:112 #Trained:224 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.93% Speed(reviews/sec):223.3 #Correct:113 #Trained:225 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.93% Speed(reviews/sec):223.4 #Correct:113 #Trained:226 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.94% Speed(reviews/sec):223.5 #Correct:114 #Trained:227 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.94% Speed(reviews/sec):223.2 #Correct:114 #Trained:228 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):222.6 #Correct:115 #Trained:229 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):222.7 #Correct:115 #Trained:230 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.95% Speed(reviews/sec):222.6 #Correct:116 #Trained:231 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.96% Speed(reviews/sec):222.7 #Correct:116 #Trained:232 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.96% Speed(reviews/sec):222.9 #Correct:117 #Trained:233 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):222.9 #Correct:117 #Trained:234 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):222.6 #Correct:118 #Trained:235 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.97% Speed(reviews/sec):222.5 #Correct:118 #Trained:236 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.98% Speed(reviews/sec):222.6 #Correct:119 #Trained:237 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.98% Speed(reviews/sec):222.5 #Correct:119 #Trained:238 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:0.99% Speed(reviews/sec):222.4 #Correct:120 #Trained:239 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:0.99% Speed(reviews/sec):222.3 #Correct:120 #Trained:240 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.0% Speed(reviews/sec):222.2 #Correct:121 #Trained:241 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:1.00% Speed(reviews/sec):222.1 #Correct:121 #Trained:242 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.00% Speed(reviews/sec):222.0 #Correct:122 #Trained:243 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:1.01% Speed(reviews/sec):221.7 #Correct:122 #Trained:244 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.01% Speed(reviews/sec):221.6 #Correct:123 #Trained:245 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):221.5 #Correct:123 #Trained:246 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):221.4 #Correct:124 #Trained:247 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:1.02% Speed(reviews/sec):221.3 #Correct:124 #Trained:248 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.03% Speed(reviews/sec):221.2 #Correct:125 #Trained:249 Training Accuracy:50.2%The shape of layer_0 is  (1, 74074)
# Progress:1.03% Speed(reviews/sec):221.1 #Correct:125 #Trained:250 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.04% Speed(reviews/sec):221.0 #Correct:126 #Trained:251 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.04% Speed(reviews/sec):220.7 #Correct:126 #Trained:252 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):220.4 #Correct:127 #Trained:253 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):220.4 #Correct:127 #Trained:254 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.05% Speed(reviews/sec):220.3 #Correct:128 #Trained:255 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.06% Speed(reviews/sec):220.2 #Correct:128 #Trained:256 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.06% Speed(reviews/sec):220.3 #Correct:129 #Trained:257 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):220.2 #Correct:129 #Trained:258 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):220.1 #Correct:130 #Trained:259 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.07% Speed(reviews/sec):220.2 #Correct:130 #Trained:260 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.08% Speed(reviews/sec):220.1 #Correct:131 #Trained:261 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.08% Speed(reviews/sec):220.0 #Correct:131 #Trained:262 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.09% Speed(reviews/sec):220.1 #Correct:132 #Trained:263 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.09% Speed(reviews/sec):220.1 #Correct:132 #Trained:264 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.1% Speed(reviews/sec):220.0 #Correct:133 #Trained:265 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.10% Speed(reviews/sec):220.1 #Correct:133 #Trained:266 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.10% Speed(reviews/sec):220.0 #Correct:134 #Trained:267 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.11% Speed(reviews/sec):219.9 #Correct:134 #Trained:268 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.11% Speed(reviews/sec):219.7 #Correct:135 #Trained:269 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):219.6 #Correct:135 #Trained:270 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):219.3 #Correct:136 #Trained:271 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.12% Speed(reviews/sec):219.3 #Correct:136 #Trained:272 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.13% Speed(reviews/sec):219.4 #Correct:137 #Trained:273 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.13% Speed(reviews/sec):219.3 #Correct:137 #Trained:274 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.14% Speed(reviews/sec):219.2 #Correct:138 #Trained:275 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.14% Speed(reviews/sec):219.1 #Correct:138 #Trained:276 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):219.1 #Correct:139 #Trained:277 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):219.0 #Correct:139 #Trained:278 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.15% Speed(reviews/sec):218.9 #Correct:140 #Trained:279 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.16% Speed(reviews/sec):219.0 #Correct:140 #Trained:280 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.16% Speed(reviews/sec):218.9 #Correct:141 #Trained:281 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):218.9 #Correct:141 #Trained:282 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):218.8 #Correct:142 #Trained:283 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.17% Speed(reviews/sec):218.7 #Correct:142 #Trained:284 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.18% Speed(reviews/sec):218.8 #Correct:143 #Trained:285 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.18% Speed(reviews/sec):218.6 #Correct:143 #Trained:286 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.19% Speed(reviews/sec):218.7 #Correct:144 #Trained:287 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.19% Speed(reviews/sec):218.5 #Correct:144 #Trained:288 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.2% Speed(reviews/sec):218.6 #Correct:145 #Trained:289 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.20% Speed(reviews/sec):218.3 #Correct:145 #Trained:290 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.20% Speed(reviews/sec):218.1 #Correct:146 #Trained:291 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.21% Speed(reviews/sec):218.0 #Correct:146 #Trained:292 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.21% Speed(reviews/sec):218.0 #Correct:147 #Trained:293 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):217.9 #Correct:147 #Trained:294 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):217.8 #Correct:148 #Trained:295 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.22% Speed(reviews/sec):217.8 #Correct:148 #Trained:296 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.23% Speed(reviews/sec):217.7 #Correct:149 #Trained:297 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.23% Speed(reviews/sec):217.8 #Correct:149 #Trained:298 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.24% Speed(reviews/sec):217.7 #Correct:150 #Trained:299 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.24% Speed(reviews/sec):217.5 #Correct:150 #Trained:300 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):217.6 #Correct:151 #Trained:301 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):217.5 #Correct:151 #Trained:302 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.25% Speed(reviews/sec):217.6 #Correct:152 #Trained:303 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.26% Speed(reviews/sec):217.6 #Correct:152 #Trained:304 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.26% Speed(reviews/sec):217.5 #Correct:153 #Trained:305 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):217.5 #Correct:153 #Trained:306 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):217.4 #Correct:154 #Trained:307 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.27% Speed(reviews/sec):217.5 #Correct:154 #Trained:308 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.28% Speed(reviews/sec):217.4 #Correct:155 #Trained:309 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.28% Speed(reviews/sec):217.4 #Correct:155 #Trained:310 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.29% Speed(reviews/sec):217.5 #Correct:156 #Trained:311 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.29% Speed(reviews/sec):217.4 #Correct:156 #Trained:312 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.3% Speed(reviews/sec):217.3 #Correct:157 #Trained:313 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.30% Speed(reviews/sec):217.4 #Correct:157 #Trained:314 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.30% Speed(reviews/sec):217.5 #Correct:158 #Trained:315 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.31% Speed(reviews/sec):217.5 #Correct:158 #Trained:316 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.31% Speed(reviews/sec):217.4 #Correct:159 #Trained:317 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):217.5 #Correct:159 #Trained:318 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):217.4 #Correct:160 #Trained:319 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.32% Speed(reviews/sec):217.5 #Correct:160 #Trained:320 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.33% Speed(reviews/sec):217.6 #Correct:161 #Trained:321 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.33% Speed(reviews/sec):217.7 #Correct:161 #Trained:322 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.34% Speed(reviews/sec):217.7 #Correct:162 #Trained:323 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.34% Speed(reviews/sec):217.7 #Correct:162 #Trained:324 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):217.8 #Correct:163 #Trained:325 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):217.9 #Correct:163 #Trained:326 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.35% Speed(reviews/sec):217.9 #Correct:164 #Trained:327 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.36% Speed(reviews/sec):217.8 #Correct:164 #Trained:328 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.36% Speed(reviews/sec):217.7 #Correct:165 #Trained:329 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):217.6 #Correct:165 #Trained:330 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):217.5 #Correct:166 #Trained:331 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.37% Speed(reviews/sec):217.6 #Correct:166 #Trained:332 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.38% Speed(reviews/sec):217.5 #Correct:167 #Trained:333 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.38% Speed(reviews/sec):217.6 #Correct:167 #Trained:334 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.39% Speed(reviews/sec):217.6 #Correct:168 #Trained:335 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.39% Speed(reviews/sec):217.6 #Correct:168 #Trained:336 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.4% Speed(reviews/sec):217.7 #Correct:169 #Trained:337 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.40% Speed(reviews/sec):217.7 #Correct:169 #Trained:338 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.40% Speed(reviews/sec):217.8 #Correct:170 #Trained:339 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.41% Speed(reviews/sec):217.8 #Correct:170 #Trained:340 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.41% Speed(reviews/sec):217.9 #Correct:171 #Trained:341 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):218.0 #Correct:171 #Trained:342 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):218.1 #Correct:172 #Trained:343 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.42% Speed(reviews/sec):218.0 #Correct:172 #Trained:344 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.43% Speed(reviews/sec):218.0 #Correct:173 #Trained:345 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.43% Speed(reviews/sec):217.9 #Correct:173 #Trained:346 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.44% Speed(reviews/sec):217.9 #Correct:174 #Trained:347 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.44% Speed(reviews/sec):218.0 #Correct:174 #Trained:348 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):217.9 #Correct:175 #Trained:349 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):218.0 #Correct:175 #Trained:350 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.45% Speed(reviews/sec):217.9 #Correct:176 #Trained:351 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.46% Speed(reviews/sec):218.0 #Correct:176 #Trained:352 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.46% Speed(reviews/sec):217.8 #Correct:177 #Trained:353 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):217.9 #Correct:177 #Trained:354 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):217.8 #Correct:178 #Trained:355 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.47% Speed(reviews/sec):217.8 #Correct:178 #Trained:356 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.48% Speed(reviews/sec):217.9 #Correct:179 #Trained:357 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.48% Speed(reviews/sec):217.8 #Correct:179 #Trained:358 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.49% Speed(reviews/sec):217.9 #Correct:180 #Trained:359 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.49% Speed(reviews/sec):217.8 #Correct:180 #Trained:360 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.5% Speed(reviews/sec):217.9 #Correct:181 #Trained:361 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.50% Speed(reviews/sec):217.9 #Correct:181 #Trained:362 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.50% Speed(reviews/sec):217.9 #Correct:182 #Trained:363 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.51% Speed(reviews/sec):217.9 #Correct:182 #Trained:364 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.51% Speed(reviews/sec):218.0 #Correct:183 #Trained:365 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):218.0 #Correct:183 #Trained:366 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):218.0 #Correct:184 #Trained:367 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.52% Speed(reviews/sec):217.9 #Correct:184 #Trained:368 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.53% Speed(reviews/sec):217.9 #Correct:185 #Trained:369 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.53% Speed(reviews/sec):218.0 #Correct:185 #Trained:370 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.54% Speed(reviews/sec):217.9 #Correct:186 #Trained:371 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.54% Speed(reviews/sec):217.9 #Correct:186 #Trained:372 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):217.8 #Correct:187 #Trained:373 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):217.8 #Correct:187 #Trained:374 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.55% Speed(reviews/sec):217.7 #Correct:188 #Trained:375 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.56% Speed(reviews/sec):217.8 #Correct:188 #Trained:376 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.56% Speed(reviews/sec):217.9 #Correct:189 #Trained:377 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):217.8 #Correct:189 #Trained:378 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):217.8 #Correct:190 #Trained:379 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.57% Speed(reviews/sec):217.7 #Correct:190 #Trained:380 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.58% Speed(reviews/sec):217.8 #Correct:191 #Trained:381 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.58% Speed(reviews/sec):217.9 #Correct:191 #Trained:382 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.59% Speed(reviews/sec):217.8 #Correct:192 #Trained:383 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.59% Speed(reviews/sec):217.8 #Correct:192 #Trained:384 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:1.6% Speed(reviews/sec):217.8 #Correct:193 #Trained:385 Training Accuracy:50.1%The shape of layer_0 is  (1, 74074)
# Progress:1.60% Speed(reviews/sec):217.8 #Correct:193 #Trained:386 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# ...
# Progress:7.21% Speed(reviews/sec):210.5 #Correct:866 #Trained:1732 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.21% Speed(reviews/sec):210.5 #Correct:867 #Trained:1733 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.22% Speed(reviews/sec):210.5 #Correct:867 #Trained:1734 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.22% Speed(reviews/sec):210.5 #Correct:868 #Trained:1735 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.22% Speed(reviews/sec):210.5 #Correct:868 #Trained:1736 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.23% Speed(reviews/sec):210.4 #Correct:869 #Trained:1737 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.23% Speed(reviews/sec):210.4 #Correct:869 #Trained:1738 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.24% Speed(reviews/sec):210.4 #Correct:870 #Trained:1739 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.24% Speed(reviews/sec):210.4 #Correct:870 #Trained:1740 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.25% Speed(reviews/sec):210.4 #Correct:871 #Trained:1741 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.25% Speed(reviews/sec):210.4 #Correct:871 #Trained:1742 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.25% Speed(reviews/sec):210.4 #Correct:872 #Trained:1743 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.26% Speed(reviews/sec):210.4 #Correct:872 #Trained:1744 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.26% Speed(reviews/sec):210.4 #Correct:873 #Trained:1745 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.27% Speed(reviews/sec):210.4 #Correct:873 #Trained:1746 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.27% Speed(reviews/sec):210.4 #Correct:874 #Trained:1747 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.27% Speed(reviews/sec):210.4 #Correct:874 #Trained:1748 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.28% Speed(reviews/sec):210.4 #Correct:875 #Trained:1749 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.28% Speed(reviews/sec):210.4 #Correct:875 #Trained:1750 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.29% Speed(reviews/sec):210.4 #Correct:876 #Trained:1751 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.29% Speed(reviews/sec):210.4 #Correct:876 #Trained:1752 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.3% Speed(reviews/sec):210.4 #Correct:877 #Trained:1753 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.30% Speed(reviews/sec):210.4 #Correct:877 #Trained:1754 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.30% Speed(reviews/sec):210.4 #Correct:878 #Trained:1755 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.31% Speed(reviews/sec):210.4 #Correct:878 #Trained:1756 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.31% Speed(reviews/sec):210.4 #Correct:879 #Trained:1757 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.32% Speed(reviews/sec):210.4 #Correct:879 #Trained:1758 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.32% Speed(reviews/sec):210.4 #Correct:880 #Trained:1759 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.32% Speed(reviews/sec):210.4 #Correct:880 #Trained:1760 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.33% Speed(reviews/sec):210.4 #Correct:881 #Trained:1761 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.33% Speed(reviews/sec):210.4 #Correct:881 #Trained:1762 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.34% Speed(reviews/sec):210.4 #Correct:882 #Trained:1763 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.34% Speed(reviews/sec):210.4 #Correct:882 #Trained:1764 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.35% Speed(reviews/sec):210.5 #Correct:883 #Trained:1765 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.35% Speed(reviews/sec):210.5 #Correct:883 #Trained:1766 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.35% Speed(reviews/sec):210.5 #Correct:884 #Trained:1767 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.36% Speed(reviews/sec):210.5 #Correct:884 #Trained:1768 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.36% Speed(reviews/sec):210.5 #Correct:885 #Trained:1769 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.37% Speed(reviews/sec):210.5 #Correct:885 #Trained:1770 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.37% Speed(reviews/sec):210.5 #Correct:886 #Trained:1771 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.37% Speed(reviews/sec):210.5 #Correct:886 #Trained:1772 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.38% Speed(reviews/sec):210.5 #Correct:887 #Trained:1773 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.38% Speed(reviews/sec):210.5 #Correct:887 #Trained:1774 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.39% Speed(reviews/sec):210.4 #Correct:888 #Trained:1775 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.39% Speed(reviews/sec):210.4 #Correct:888 #Trained:1776 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.4% Speed(reviews/sec):210.4 #Correct:889 #Trained:1777 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.40% Speed(reviews/sec):210.4 #Correct:889 #Trained:1778 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.40% Speed(reviews/sec):210.4 #Correct:890 #Trained:1779 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.41% Speed(reviews/sec):210.4 #Correct:890 #Trained:1780 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.41% Speed(reviews/sec):210.4 #Correct:891 #Trained:1781 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.42% Speed(reviews/sec):210.4 #Correct:891 #Trained:1782 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.42% Speed(reviews/sec):210.4 #Correct:892 #Trained:1783 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.42% Speed(reviews/sec):210.4 #Correct:892 #Trained:1784 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.43% Speed(reviews/sec):210.4 #Correct:893 #Trained:1785 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.43% Speed(reviews/sec):210.4 #Correct:893 #Trained:1786 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.44% Speed(reviews/sec):210.4 #Correct:894 #Trained:1787 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.44% Speed(reviews/sec):210.4 #Correct:894 #Trained:1788 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.45% Speed(reviews/sec):210.4 #Correct:895 #Trained:1789 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.45% Speed(reviews/sec):210.5 #Correct:895 #Trained:1790 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.45% Speed(reviews/sec):210.5 #Correct:896 #Trained:1791 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.46% Speed(reviews/sec):210.5 #Correct:896 #Trained:1792 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.46% Speed(reviews/sec):210.5 #Correct:897 #Trained:1793 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.47% Speed(reviews/sec):210.5 #Correct:897 #Trained:1794 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.47% Speed(reviews/sec):210.5 #Correct:898 #Trained:1795 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.47% Speed(reviews/sec):210.5 #Correct:898 #Trained:1796 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.48% Speed(reviews/sec):210.5 #Correct:899 #Trained:1797 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.48% Speed(reviews/sec):210.5 #Correct:899 #Trained:1798 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.49% Speed(reviews/sec):210.6 #Correct:900 #Trained:1799 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.49% Speed(reviews/sec):210.5 #Correct:900 #Trained:1800 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.5% Speed(reviews/sec):210.6 #Correct:901 #Trained:1801 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.50% Speed(reviews/sec):210.6 #Correct:901 #Trained:1802 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.50% Speed(reviews/sec):210.6 #Correct:902 #Trained:1803 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.51% Speed(reviews/sec):210.6 #Correct:902 #Trained:1804 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.51% Speed(reviews/sec):210.6 #Correct:903 #Trained:1805 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.52% Speed(reviews/sec):210.6 #Correct:903 #Trained:1806 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.52% Speed(reviews/sec):210.6 #Correct:904 #Trained:1807 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.52% Speed(reviews/sec):210.6 #Correct:904 #Trained:1808 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.53% Speed(reviews/sec):210.5 #Correct:905 #Trained:1809 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.53% Speed(reviews/sec):210.5 #Correct:905 #Trained:1810 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.54% Speed(reviews/sec):210.6 #Correct:906 #Trained:1811 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.54% Speed(reviews/sec):210.6 #Correct:906 #Trained:1812 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.55% Speed(reviews/sec):210.5 #Correct:907 #Trained:1813 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.55% Speed(reviews/sec):210.5 #Correct:907 #Trained:1814 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.55% Speed(reviews/sec):210.5 #Correct:908 #Trained:1815 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.56% Speed(reviews/sec):210.5 #Correct:908 #Trained:1816 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.56% Speed(reviews/sec):210.5 #Correct:909 #Trained:1817 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.57% Speed(reviews/sec):210.5 #Correct:909 #Trained:1818 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.57% Speed(reviews/sec):210.5 #Correct:910 #Trained:1819 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.57% Speed(reviews/sec):210.5 #Correct:910 #Trained:1820 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.58% Speed(reviews/sec):210.5 #Correct:911 #Trained:1821 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.58% Speed(reviews/sec):210.5 #Correct:911 #Trained:1822 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.59% Speed(reviews/sec):210.5 #Correct:912 #Trained:1823 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.59% Speed(reviews/sec):210.5 #Correct:912 #Trained:1824 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.6% Speed(reviews/sec):210.5 #Correct:913 #Trained:1825 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.60% Speed(reviews/sec):210.5 #Correct:913 #Trained:1826 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.60% Speed(reviews/sec):210.5 #Correct:914 #Trained:1827 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.61% Speed(reviews/sec):210.5 #Correct:914 #Trained:1828 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.61% Speed(reviews/sec):210.6 #Correct:915 #Trained:1829 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.62% Speed(reviews/sec):210.5 #Correct:915 #Trained:1830 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.62% Speed(reviews/sec):210.6 #Correct:916 #Trained:1831 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.62% Speed(reviews/sec):210.6 #Correct:916 #Trained:1832 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.63% Speed(reviews/sec):210.6 #Correct:917 #Trained:1833 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.63% Speed(reviews/sec):210.6 #Correct:917 #Trained:1834 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.64% Speed(reviews/sec):210.6 #Correct:918 #Trained:1835 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.64% Speed(reviews/sec):210.6 #Correct:918 #Trained:1836 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.65% Speed(reviews/sec):210.6 #Correct:919 #Trained:1837 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.65% Speed(reviews/sec):210.6 #Correct:919 #Trained:1838 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.65% Speed(reviews/sec):210.7 #Correct:920 #Trained:1839 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.66% Speed(reviews/sec):210.7 #Correct:920 #Trained:1840 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.66% Speed(reviews/sec):210.7 #Correct:921 #Trained:1841 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.67% Speed(reviews/sec):210.7 #Correct:921 #Trained:1842 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.67% Speed(reviews/sec):210.7 #Correct:922 #Trained:1843 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.67% Speed(reviews/sec):210.7 #Correct:922 #Trained:1844 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.68% Speed(reviews/sec):210.7 #Correct:923 #Trained:1845 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.68% Speed(reviews/sec):210.7 #Correct:923 #Trained:1846 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.69% Speed(reviews/sec):210.8 #Correct:924 #Trained:1847 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.69% Speed(reviews/sec):210.8 #Correct:924 #Trained:1848 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.7% Speed(reviews/sec):210.8 #Correct:925 #Trained:1849 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.70% Speed(reviews/sec):210.8 #Correct:925 #Trained:1850 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.70% Speed(reviews/sec):210.8 #Correct:926 #Trained:1851 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.71% Speed(reviews/sec):210.8 #Correct:926 #Trained:1852 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.71% Speed(reviews/sec):210.8 #Correct:927 #Trained:1853 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.72% Speed(reviews/sec):210.8 #Correct:927 #Trained:1854 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.72% Speed(reviews/sec):210.9 #Correct:928 #Trained:1855 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.72% Speed(reviews/sec):210.9 #Correct:928 #Trained:1856 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.73% Speed(reviews/sec):210.9 #Correct:929 #Trained:1857 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
# Progress:7.73% Speed(reviews/sec):210.9 #Correct:929 #Trained:1858 Training Accuracy:50.0%The shape of layer_0 is  (1, 74074)
